# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading the data
df=pd.read_excel(r"C:\Users\aalme\OneDrive\Desktop\PROJECT\ABC_manufacturing_processed_final.xlsx",header=0)

# %%
df.head()
# Out:
#     FIN_YEAR MONTH    STATE            FG     DISTRICT            COMPANY  \
# 0  2014-2015   May  Haryana  Insecticides       Ambala  ABC Manufacturing
# 1  2014-2015   May  Haryana  Insecticides  Yamunanagar  ABC Manufacturing
# 2  2014-2015   May  Haryana  Insecticides  Kurukshetra  ABC Manufacturing
# 3  2014-2015   May  Haryana  Insecticides       Karnal  ABC Manufacturing
# 4  2014-2015   May  Haryana  Insecticides      Panipat  ABC Manufacturing
#
#     VALUE_x     DATE_1  Rainfall in  mm     DATE_2 month_full    Year  \
# 0   252.720 2015-05-01             20.5 2014-05-01        May  2014.0
# 1   933.255 2015-05-01             26.8 2014-05-01        May  2014.0
# 2  2675.430 2015-05-01              4.2 2014-05-01        May  2014.0
# 3  3436.830 2015-05-01             29.7 2014-05-01        May  2014.0
# 4   472.770 2015-05-01             21.5 2014-05-01        May  2014.0
#
#   As Quarter  Fiscal Year
# 0     2015Q1       2015.0
# 1     2015Q1       2015.0
# 2     2015Q1       2015.0
# 3     2015Q1       2015.0
# 4     2015Q1       2015.0

# %%
df.dtypes
# Out:
# FIN_YEAR                   object
# MONTH                      object
# STATE                      object
# FG                         object
# DISTRICT                   object
# COMPANY                    object
# VALUE_x                   float64
# DATE_1             datetime64[ns]
# Rainfall in  mm           float64
# DATE_2             datetime64[ns]
# month_full                 object
# Year                      float64
# As Quarter                 object
# Fiscal Year               float64
# dtype: object

# %%
df["STATE"].value_counts()
# Out:
# Uttar Pradesh       13024
# Haryana              6028
# Himachal Pradesh     3880
# Punjab               3668
# Uttarakhand          2040
# Name: STATE, dtype: int64

# %%
df["COMPANY"].value_counts()
# Out:
# ABC Manufacturing    28640
# Name: COMPANY, dtype: int64

# %%
#Doing Statewise prediction
company_state =  df[df['STATE']=='Uttar Pradesh']

# %%
company_state.shape
# Out:
# (13024, 14)

# %%
company_state.head()
# Out:
#         FIN_YEAR MONTH          STATE            FG       DISTRICT  \
# 13576  2014-2015   May  Uttar Pradesh  Insecticides     Saharanpur
# 13577  2014-2015   May  Uttar Pradesh  Insecticides  Muzaffarnagar
# 13578  2014-2015   May  Uttar Pradesh  Insecticides         Bijnor
# 13579  2014-2015   May  Uttar Pradesh  Insecticides         Rampur
# 13580  2014-2015   May  Uttar Pradesh  Insecticides         Meerut
#
#                  COMPANY    VALUE_x     DATE_1  Rainfall in  mm     DATE_2  \
# 13576  ABC Manufacturing  16268.310 2015-05-01             12.7 2014-05-01
# 13577  ABC Manufacturing  36879.030 2015-05-01             30.2 2014-05-01
# 13578  ABC Manufacturing  39315.375 2015-05-01             45.9 2014-05-01
# 13579  ABC Manufacturing  11955.060 2015-05-01              3.5 2014-05-01
# 13580  ABC Manufacturing  31395.870 2015-05-01             28.2 2014-05-01
#
#       month_full    Year As Quarter  Fiscal Year
# 13576        May  2014.0     2015Q1       2015.0
# 13577        May  2014.0     2015Q1       2015.0
# 13578        May  2014.0     2015Q1       2015.0
# 13579        May  2014.0     2015Q1       2015.0
# 13580        May  2014.0     2015Q1       2015.0

# %%
company_state =company_state[['DATE_1','VALUE_x']]

# %%
company_state.shape
# Out:
# (13024, 2)

# %%
company_state['DATE_1'].min(), company_state['DATE_1'].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2018-12-01 00:00:00'))

# %%
company = company_state.sort_values('DATE_1', ascending=True)
company.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
company.head()
# Out:
#           DATE_1  VALUE_x
# 15709 2015-01-01  129.600
# 15675 2015-01-01  370.170
# 15674 2015-01-01    0.000
# 15673 2015-01-01  298.215
# 15672 2015-01-01  278.100

# %%
company["DATE_1"].value_counts()
# Out:
# 2018-12-01    300
# 2018-11-01    300
# 2018-10-01    300
# 2018-09-01    300
# 2018-06-01    300
# 2018-08-01    296
# 2018-07-01    296
# 2018-01-01    292
# 2016-07-01    292
# 2017-07-01    288
# 2017-01-01    288
# 2017-02-01    288
# 2017-03-01    288
# 2017-11-01    288
# 2017-08-01    288
# 2017-09-01    288
# 2017-10-01    288
# 2016-10-01    288
# 2017-12-01    288
# 2016-11-01    288
# 2015-01-01    288
# 2016-09-01    288
# 2016-02-01    288
# 2015-03-01    288
# 2015-08-01    288
# 2015-09-01    288
# 2015-10-01    288
# 2015-11-01    288
# 2016-08-01    288
# 2016-01-01    288
# 2015-12-01    288
# 2016-03-01    288
# 2016-12-01    288
# 2015-07-01    284
# 2015-02-01    284
# 2018-05-01    280
# 2015-06-01    280
# 2016-06-01    276
# 2016-04-01    272
# 2017-06-01    264
# 2017-05-01    264
# 2016-05-01    264
# 2018-04-01    256
# 2017-04-01    248
# 2015-05-01    248
# 2015-04-01    216
# Name: DATE_1, dtype: int64

# %%
company.dtypes
# Out:
# DATE_1     datetime64[ns]
# VALUE_x           float64
# dtype: object

# %%
company = company_state.sort_values('DATE_1', ascending=True)
company.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
company.head(10)
# Out:
#           DATE_1  VALUE_x
# 15709 2015-01-01  129.600
# 15675 2015-01-01  370.170
# 15674 2015-01-01    0.000
# 15673 2015-01-01  298.215
# 15672 2015-01-01  278.100
# 15671 2015-01-01  594.540
# 15670 2015-01-01    0.000
# 15669 2015-01-01    0.000
# 15668 2015-01-01    0.000
# 15667 2015-01-01    0.675

# %%
company["DATE_1"].value_counts()
# Out:
# 2018-12-01    300
# 2018-11-01    300
# 2018-10-01    300
# 2018-09-01    300
# 2018-06-01    300
# 2018-08-01    296
# 2018-07-01    296
# 2018-01-01    292
# 2016-07-01    292
# 2017-07-01    288
# 2017-01-01    288
# 2017-02-01    288
# 2017-03-01    288
# 2017-11-01    288
# 2017-08-01    288
# 2017-09-01    288
# 2017-10-01    288
# 2016-10-01    288
# 2017-12-01    288
# 2016-11-01    288
# 2015-01-01    288
# 2016-09-01    288
# 2016-02-01    288
# 2015-03-01    288
# 2015-08-01    288
# 2015-09-01    288
# 2015-10-01    288
# 2015-11-01    288
# 2016-08-01    288
# 2016-01-01    288
# 2015-12-01    288
# 2016-03-01    288
# 2016-12-01    288
# 2015-07-01    284
# 2015-02-01    284
# 2018-05-01    280
# 2015-06-01    280
# 2016-06-01    276
# 2016-04-01    272
# 2017-06-01    264
# 2017-05-01    264
# 2016-05-01    264
# 2018-04-01    256
# 2017-04-01    248
# 2015-05-01    248
# 2015-04-01    216
# Name: DATE_1, dtype: int64

# %%
company = company.groupby('DATE_1')["VALUE_x"].sum().reset_index()
company.shape
# Out:
# (46, 2)

# %%
company.head(10)
# Out:
#       DATE_1      VALUE_x
# 0 2015-01-01   817419.600
# 1 2015-02-01   662409.630
# 2 2015-03-01  1641843.540
# 3 2015-04-01   142695.000
# 4 2015-05-01   395083.710
# 5 2015-06-01   553862.070
# 6 2015-07-01   720928.080
# 7 2015-08-01  1103308.965
# 8 2015-09-01   752904.720
# 9 2015-10-01   708021.540

# %%
company = company.set_index("DATE_1")

# %%
company.head(10)
# Out:
#                 VALUE_x
# DATE_1
# 2015-01-01   817419.600
# 2015-02-01   662409.630
# 2015-03-01  1641843.540
# 2015-04-01   142695.000
# 2015-05-01   395083.710
# 2015-06-01   553862.070
# 2015-07-01   720928.080
# 2015-08-01  1103308.965
# 2015-09-01   752904.720
# 2015-10-01   708021.540

# %%
y = company['VALUE_x'].resample('M').sum()

# %%
print(y.shape)
# Out:
# (48,)

# %%
y.isnull().sum()
# Out:
# 0

# %%
y
# Out:
# DATE_1
# 2015-01-31     817419.600
# 2015-02-28     662409.630
# 2015-03-31    1641843.540
# 2015-04-30     142695.000
# 2015-05-31     395083.710
# 2015-06-30     553862.070
# 2015-07-31     720928.080
# 2015-08-31    1103308.965
# 2015-09-30     752904.720
# 2015-10-31     708021.540
# 2015-11-30    1431476.820
# 2015-12-31    1049625.270
# 2016-01-31     789729.885
# 2016-02-29     541337.310
# 2016-03-31    2039066.595
# 2016-04-30     503665.560
# 2016-05-31     711111.285
# 2016-06-30     700414.290
# 2016-07-31     914662.530
# 2016-08-31     824892.660
# 2016-09-30     825032.385
# 2016-10-31     660813.660
# 2016-11-30     935888.850
# 2016-12-31     845433.045
# 2017-01-31     827758.980
# 2017-02-28     581322.015
# 2017-03-31    1414752.183
# 2017-04-30     239000.760
# 2017-05-31     572291.325
# 2017-06-30     531000.900
# 2017-07-31     567115.020
# 2017-08-31     737854.650
# 2017-09-30     597814.560
# 2017-10-31     405397.035
# 2017-11-30     907754.040
# 2017-12-31     831337.992
# 2018-01-31     734645.700
# 2018-02-28          0.000
# 2018-03-31          0.000
# 2018-04-30     132897.240
# 2018-05-31     516515.670
# 2018-06-30     483089.130
# 2018-07-31     569271.915
# 2018-08-31     597466.935
# 2018-09-30     539775.090
# 2018-10-31     720295.875
# 2018-11-30    1234663.965
# 2018-12-31     991006.515
# Freq: M, Name: VALUE_x, dtype: float64

# %%
y.shape
# Out:
# (48,)

# %%
y.plot(figsize=(20,8))
plt.show()

# %%
train = y.loc[:'2017-08-31']
print(train.shape)
train
# Out:
# (32,)
# DATE_1
# 2015-01-31     817419.600
# 2015-02-28     662409.630
# 2015-03-31    1641843.540
# 2015-04-30     142695.000
# 2015-05-31     395083.710
# 2015-06-30     553862.070
# 2015-07-31     720928.080
# 2015-08-31    1103308.965
# 2015-09-30     752904.720
# 2015-10-31     708021.540
# 2015-11-30    1431476.820
# 2015-12-31    1049625.270
# 2016-01-31     789729.885
# 2016-02-29     541337.310
# 2016-03-31    2039066.595
# 2016-04-30     503665.560
# 2016-05-31     711111.285
# 2016-06-30     700414.290
# 2016-07-31     914662.530
# 2016-08-31     824892.660
# 2016-09-30     825032.385
# 2016-10-31     660813.660
# 2016-11-30     935888.850
# 2016-12-31     845433.045
# 2017-01-31     827758.980
# 2017-02-28     581322.015
# 2017-03-31    1414752.183
# 2017-04-30     239000.760
# 2017-05-31     572291.325
# 2017-06-30     531000.900
# 2017-07-31     567115.020
# 2017-08-31     737854.650
# Freq: M, Name: VALUE_x, dtype: float64

# %%
test = y.loc['2017-09-30':]
print(test.shape)
test
# Out:
# (16,)
# DATE_1
# 2017-09-30     597814.560
# 2017-10-31     405397.035
# 2017-11-30     907754.040
# 2017-12-31     831337.992
# 2018-01-31     734645.700
# 2018-02-28          0.000
# 2018-03-31          0.000
# 2018-04-30     132897.240
# 2018-05-31     516515.670
# 2018-06-30     483089.130
# 2018-07-31     569271.915
# 2018-08-31     597466.935
# 2018-09-30     539775.090
# 2018-10-31     720295.875
# 2018-11-30    1234663.965
# 2018-12-31     991006.515
# Freq: M, Name: VALUE_x, dtype: float64

# %%
train.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
test.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
plt.show()

# %% [markdown]
# # Calculating Rolling Statistics

# %%
#determining rolling statistics (rolling mean at yearly level window=12)
rolmean=company.rolling(window=12).mean()


print(rolmean)
# Out:
#                  VALUE_x
# DATE_1
# 2015-01-01           NaN
# 2015-02-01           NaN
# 2015-03-01           NaN
# 2015-04-01           NaN
# 2015-05-01           NaN
# 2015-06-01           NaN
# 2015-07-01           NaN
# 2015-08-01           NaN
# 2015-09-01           NaN
# 2015-10-01           NaN
# 2015-11-01           NaN
# 2015-12-01  831631.57875
# 2016-01-01  829324.10250
# 2016-02-01  819234.74250
# 2016-03-01  852336.66375
# 2016-04-01  882417.54375
# 2016-05-01  908753.17500
# 2016-06-01  920965.86000
# 2016-07-01  937110.39750
# 2016-08-01  913909.03875
# 2016-09-01  919919.67750
# 2016-10-01  915985.68750
# 2016-11-01  874686.69000
# 2016-12-01  857670.67125
# 2017-01-01  860839.76250
# 2017-02-01  864171.82125
# 2017-03-01  812145.62025
# 2017-04-01  790090.22025
# 2017-05-01  778521.89025
# 2017-06-01  764404.10775
# 2017-07-01  735441.81525
# 2017-08-01  728188.64775
# 2017-09-01  709253.82900
# 2017-10-01  687969.11025
# 2017-11-01  685624.54275
# 2017-12-01  684449.95500
# 2018-01-01  676690.51500
# 2018-04-01  639321.78375
# 2018-05-01  564468.74100
# 2018-06-01  584809.43850
# 2018-07-01  584557.82100
# 2018-08-01  590096.65725
# 2018-09-01  587818.32975
# 2018-10-01  586355.09850
# 2018-11-01  639425.88225
# 2018-12-01  688226.67225

# %%
rolstd=company.rolling(window=12).std()
print(rolstd)
# Out:
#                   VALUE_x
# DATE_1
# 2015-01-01            NaN
# 2015-02-01            NaN
# 2015-03-01            NaN
# 2015-04-01            NaN
# 2015-05-01            NaN
# 2015-06-01            NaN
# 2015-07-01            NaN
# 2015-08-01            NaN
# 2015-09-01            NaN
# 2015-10-01            NaN
# 2015-11-01            NaN
# 2015-12-01  420229.570522
# 2016-01-01  420390.693781
# 2016-02-01  426173.897380
# 2016-03-01  504166.437819
# 2016-04-01  467405.187548
# 2016-05-01  445856.936483
# 2016-06-01  437174.822988
# 2016-07-01  432670.034874
# 2016-08-01  430406.591075
# 2016-09-01  428452.957600
# 2016-10-01  430785.825075
# 2016-11-01  399492.682809
# 2016-12-01  395694.575748
# 2017-01-01  395253.015767
# 2017-02-01  392473.454091
# 2017-03-01  230546.747794
# 2017-04-01  271723.058769
# 2017-05-01  278267.431666
# 2017-06-01  286758.450900
# 2017-07-01  287752.121679
# 2017-08-01  286386.132491
# 2017-09-01  286912.015448
# 2017-10-01  300007.512172
# 2017-11-01  297997.076706
# 2017-12-01  297336.957768
# 2018-01-01  294458.140298
# 2018-04-01  333523.949052
# 2018-05-01  227670.769452
# 2018-06-01  205802.658925
# 2018-07-01  205821.200065
# 2018-08-01  205142.120872
# 2018-09-01  205571.930008
# 2018-10-01  204466.425902
# 2018-11-01  277365.312539
# 2018-12-01  283886.647886

# %%
#plotting rolling statistics (Rolling Mean)
orig=plt.plot(y,color='blue',label="Original")
mean=plt.plot(rolmean,color='red',label='Rolling Mean')
#std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Rolling Mean ")
plt.show(block=True)

# %%
#plotting rolling statistics(Rolling Deviation)
orig=plt.plot(y,color='blue',label="Original")
#mean=plt.plot(rolmean,color='red',label='Rolling Mean')
std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Standard Deviation")
plt.show(block=False)

# %%
#ADFULLER test
from statsmodels.tsa.stattools import adfuller
print("ADfuller test")
dftest = adfuller(y,autolag ='AIC')
dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','number of observations used'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)'%key]= value
print(dfoutput)

# # we reject null hypothesis : It is Stationary
# Out:
# ADfuller test
# Test Statistic                -6.277941e+00
# p-value                        3.859215e-08
# #lags used                     0.000000e+00
# number of observations used    4.700000e+01
# critical value (1%)           -3.577848e+00
# critical value (5%)           -2.925338e+00
# critical value (10%)          -2.600774e+00
# dtype: float64

# %%
#Simple ExpSmoothening
from statsmodels.tsa.api import SimpleExpSmoothing
Exp_Smooth = test.copy()
fit1 = SimpleExpSmoothing(train).fit(smoothing_level=0.01)
Exp_Smooth['SES'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Exp_Smooth['SES'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Exp_Smooth.SES
# Out:
# 2017-09-30    803629.873156
# 2017-10-31    803629.873156
# 2017-11-30    803629.873156
# 2017-12-31    803629.873156
# 2018-01-31    803629.873156
# 2018-02-28    803629.873156
# 2018-03-31    803629.873156
# 2018-04-30    803629.873156
# 2018-05-31    803629.873156
# 2018-06-30    803629.873156
# 2018-07-31    803629.873156
# 2018-08-31    803629.873156
# 2018-09-30    803629.873156
# 2018-10-31    803629.873156
# 2018-11-30    803629.873156
# 2018-12-31    803629.873156
# Freq: M, dtype: float64

# %%
fit1.aic
# Out:
# 826.7082528756224

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Exp_Smooth.SES))
print(rmse)
# Out:
# 398349.2488738175

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(y)
fig = decomposition.plot()
plt.show()

# %%
# Double ExpSmoothening
from statsmodels.tsa.api import Holt
Holt_df = test.copy()
#soothing slope = beta
fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
Holt_df['Holt_linear'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_df['Holt_linear'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\AppData\Local\Temp/ipykernel_17432/527924908.py:5: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 836.5605505277459

# %%
Holt_df['Holt_linear']
# Out:
# 2017-09-30    553798.359071
# 2017-10-31    536569.039608
# 2017-11-30    519339.720145
# 2017-12-31    502110.400682
# 2018-01-31    484881.081219
# 2018-02-28    467651.761756
# 2018-03-31    450422.442293
# 2018-04-30    433193.122829
# 2018-05-31    415963.803366
# 2018-06-30    398734.483903
# 2018-07-31    381505.164440
# 2018-08-31    364275.844977
# 2018-09-30    347046.525514
# 2018-10-31    329817.206051
# 2018-11-30    312587.886588
# 2018-12-31    295358.567125
# Freq: M, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_df['Holt_linear']))
print(rmse)
# Out:
# 393951.74306667637

# %%
#Triple ExpSmoothening
from statsmodels.tsa.api import ExponentialSmoothing
Holt_Winter_df = test.copy()
#soothing slope = beta
fit1 = ExponentialSmoothing(train,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Holt_Winter_df['Holt_Winter'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_Winter_df['Holt_Winter'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 807.3816327863238

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_Winter_df['Holt_Winter']))
print(rmse)
# Out:
# 440729.1802086824

# %%
Holt_Winter_df['Holt_Winter']
# Out:
# 2017-09-30    6.515505e+05
# 2017-10-31    5.762176e+05
# 2017-11-30    1.188907e+06
# 2017-12-31    9.238774e+05
# 2018-01-31    7.530965e+05
# 2018-02-28    5.487247e+05
# 2018-03-31    1.595799e+06
# 2018-04-30    1.749668e+05
# 2018-05-31    4.167816e+05
# 2018-06-30    4.659224e+05
# 2018-07-31    6.088891e+05
# 2018-08-31    9.000906e+05
# 2018-09-30    6.773853e+05
# 2018-10-31    6.020524e+05
# 2018-11-30    1.214742e+06
# 2018-12-31    9.497122e+05
# Freq: M, dtype: float64

# %%
from statsmodels.tsa.api import ExponentialSmoothing


fit1 = ExponentialSmoothing(y,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Y_predictions = fit1.forecast(steps=12)

y.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)

Y_predictions.plot(figsize=(10,6), title= 'Average Sales', fontsize=14) 
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Y_predictions
# Out:
# 2019-01-31    7.287811e+05
# 2019-02-28    5.084750e+04
# 2019-03-31    2.011205e+05
# 2019-04-30    3.238600e+05
# 2019-05-31    6.924010e+05
# 2019-06-30    6.446108e+05
# 2019-07-31    7.144700e+05
# 2019-08-31    7.431037e+05
# 2019-09-30    6.776091e+05
# 2019-10-31    8.111389e+05
# 2019-11-30    1.281580e+06
# 2019-12-31    8.480502e+05
# Freq: M, dtype: float64

# %%
train.plot(figsize=(20,8), title= 'Train - Average Sales ', fontsize=14,color="black",legend=True,label="Train Average Sales")
test.plot(figsize=(20,8), title='Test - Average Sales', fontsize=14,color="grey",legend=True,label="Test Average Sales")
Exp_Smooth['SES'].plot(figsize=(20,8),  fontsize=14,color="red",legend=True,label="Simple Exponential Smoothing")                                  
Holt_df['Holt_linear'].plot(figsize=(20,8),  fontsize=14,color="green",legend=True,label="Holt Linear")                                  
Holt_Winter_df['Holt_Winter'].plot(figsize=(20,8),  fontsize=14,color="blue",legend=True,label="Holt Winter") # seems Triple smooethening
Y_predictions.plot(figsize=(10,6),  fontsize=14,color="purple",legend=True,label="Predictions") 
plt.show() 
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# # ARIMA MODEL

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(y,start_p=0, max_p=3, d=None, max_d=2,start_q=0, max_q=3,  
                      start_P=0,max_P=3, D=None, max_D=2, start_Q=0, max_Q=3,
                      max_order=10, m=12, seasonal=True, information_criterion='aic',
                      test='adf',trace=True,random_state=10)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1375.286, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1351.515, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1342.134, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1373.299, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1353.078, Time=0.00 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1342.107, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1340.674, Time=0.05 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=1342.013, Time=0.06 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=1343.980, Time=0.10 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=1359.481, Time=0.02 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=1342.548, Time=0.05 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=1344.525, Time=0.03 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=1344.549, Time=0.19 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=1338.400, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=1349.830, Time=0.02 sec
#  ARIMA(0,1,1)(2,0,0)[12]             : AIC=1339.981, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=1340.086, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=1340.031, Time=0.03 sec
#  ARIMA(0,1,1)(2,0,1)[12]             : AIC=1341.807, Time=0.10 sec
#  ARIMA(0,1,0)(1,0,0)[12]             : AIC=1351.001, Time=0.01 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=1339.931, Time=0.03 sec
#  ARIMA(0,1,2)(1,0,0)[12]             : AIC=1341.062, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=1349.527, Time=0.02 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=1342.735, Time=0.09 sec
#
# Best model:  ARIMA(0,1,1)(1,0,0)[12]
# Total fit time: 1.078 seconds

# %%
model
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(1, 0, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
model.aic()
# Out:
# 1338.399539913901

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model =SARIMAX(y, order=(0,1,1), seasonal_order=(0,0,2,12)).fit()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
Y_pred=pred.predicted_mean
Y_test=y["2018-01-01":]

from sklearn.metrics import mean_squared_error
from math import sqrt
rms=sqrt(mean_squared_error(Y_test,Y_pred))
print(rms)
# Out:
# 510626.71398616314

# %%
#pred = model.get_prediction(start=pd.to_datetime('2017-01-31')) 
pred = model.get_forecast(steps=12)

plt.figure(figsize=(10,6))
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Validation Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
pred.predicted_mean
# Out:
# 2019-01-31    8.850173e+05
# 2019-02-28    4.654257e+05
# 2019-03-31    2.923366e+05
# 2019-04-30    5.444234e+05
# 2019-05-31    7.483216e+05
# 2019-06-30    7.457697e+05
# 2019-07-31    7.854517e+05
# 2019-08-31    8.276127e+05
# 2019-09-30    7.767361e+05
# 2019-10-31    9.238970e+05
# 2019-11-30    1.223687e+06
# 2019-12-31    1.078709e+06
# Freq: M, Name: predicted_mean, dtype: float64

# %%
#pred.predicted_mean.to_excel("Timeseriesoutput.xlsx",index=True)

# %% [markdown]
# # State of Punjab

# %%
df.head(10)
# Out:
#     FIN_YEAR MONTH    STATE            FG     DISTRICT            COMPANY  \
# 0  2014-2015   May  Haryana  Insecticides       Ambala  ABC Manufacturing
# 1  2014-2015   May  Haryana  Insecticides  Yamunanagar  ABC Manufacturing
# 2  2014-2015   May  Haryana  Insecticides  Kurukshetra  ABC Manufacturing
# 3  2014-2015   May  Haryana  Insecticides       Karnal  ABC Manufacturing
# 4  2014-2015   May  Haryana  Insecticides      Panipat  ABC Manufacturing
# 5  2014-2015   May  Haryana  Insecticides         Jind  ABC Manufacturing
# 6  2014-2015   May  Haryana  Insecticides    Fatehabad  ABC Manufacturing
# 7  2014-2015   May  Haryana  Insecticides        Hisar  ABC Manufacturing
# 8  2014-2015   May  Haryana  Insecticides      Bhiwani  ABC Manufacturing
# 9  2014-2015   May  Haryana  Insecticides       Rohtak  ABC Manufacturing
#
#     VALUE_x     DATE_1  Rainfall in  mm     DATE_2 month_full    Year  \
# 0   252.720 2015-05-01             20.5 2014-05-01        May  2014.0
# 1   933.255 2015-05-01             26.8 2014-05-01        May  2014.0
# 2  2675.430 2015-05-01              4.2 2014-05-01        May  2014.0
# 3  3436.830 2015-05-01             29.7 2014-05-01        May  2014.0
# 4   472.770 2015-05-01             21.5 2014-05-01        May  2014.0
# 5  8360.415 2015-05-01             48.5 2014-05-01        May  2014.0
# 6  3989.520 2015-05-01              8.6 2014-05-01        May  2014.0
# 7  3356.910 2015-05-01             25.2 2014-05-01        May  2014.0
# 8  1738.935 2015-05-01             27.2 2014-05-01        May  2014.0
# 9   315.360 2015-05-01             11.4 2014-05-01        May  2014.0
#
#   As Quarter  Fiscal Year
# 0     2015Q1       2015.0
# 1     2015Q1       2015.0
# 2     2015Q1       2015.0
# 3     2015Q1       2015.0
# 4     2015Q1       2015.0
# 5     2015Q1       2015.0
# 6     2015Q1       2015.0
# 7     2015Q1       2015.0
# 8     2015Q1       2015.0
# 9     2015Q1       2015.0

# %%
df["STATE"].value_counts()
# Out:
# Uttar Pradesh       13024
# Haryana              6028
# Himachal Pradesh     3880
# Punjab               3668
# Uttarakhand          2040
# Name: STATE, dtype: int64

# %%
state =  df[df['STATE']=='Punjab']

# %%
state.shape
# Out:
# (3668, 14)

# %%
state
# Out:
#         FIN_YEAR MONTH   STATE            FG         DISTRICT  \
# 9908   2014-2015   May  Punjab  Insecticides        Gurdaspur
# 9909   2014-2015   May  Punjab  Insecticides       Kapurthala
# 9910   2014-2015   May  Punjab  Insecticides       Hoshiarpur
# 9911   2014-2015   May  Punjab  Insecticides  Fatehgarh Sahib
# 9912   2014-2015   May  Punjab  Insecticides         Ludhiana
# ...          ...   ...     ...           ...              ...
# 13571  2017-2018   Jul  Punjab  Bactericides         Rupnagar
# 13572  2017-2018   Dec  Punjab  Bactericides          Fazilka
# 13573  2017-2018   Jan  Punjab  Bactericides       Nawanshahr
# 13574  2017-2018   Jan  Punjab  Bactericides        Firozepur
# 13575  2017-2018   Jan  Punjab  Bactericides          Fazilka
#
#                  COMPANY    VALUE_x     DATE_1  Rainfall in  mm     DATE_2  \
# 9908   ABC Manufacturing   8078.670 2015-05-01             36.0 2014-05-01
# 9909   ABC Manufacturing   1107.540 2015-05-01              9.0 2014-05-01
# 9910   ABC Manufacturing   1182.060 2015-05-01             15.6 2014-05-01
# 9911   ABC Manufacturing   4373.460 2015-05-01              0.0 2014-05-01
# 9912   ABC Manufacturing  25632.585 2015-05-01             27.2 2014-05-01
# ...                  ...        ...        ...              ...        ...
# 13571  ABC Manufacturing      0.000 2018-07-01              0.0 2017-07-01
# 13572  ABC Manufacturing      0.000 2018-12-01              0.0        NaT
# 13573  ABC Manufacturing      0.000 2018-01-01              0.0        NaT
# 13574  ABC Manufacturing      0.000 2018-01-01              0.0        NaT
# 13575  ABC Manufacturing      0.000 2018-01-01              0.0        NaT
#
#       month_full    Year As Quarter  Fiscal Year
# 9908         May  2014.0     2015Q1       2015.0
# 9909         May  2014.0     2015Q1       2015.0
# 9910         May  2014.0     2015Q1       2015.0
# 9911         May  2014.0     2015Q1       2015.0
# 9912         May  2014.0     2015Q1       2015.0
# ...          ...     ...        ...          ...
# 13571       July  2017.0     2018Q2       2018.0
# 13572        NaN     NaN        NaN          NaN
# 13573        NaN     NaN        NaN          NaN
# 13574        NaN     NaN        NaN          NaN
# 13575        NaN     NaN        NaN          NaN
#
# [3668 rows x 14 columns]

# %%
df1 =state[['DATE_1','VALUE_x']]

# %%
df1= df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1
# Out:
#           DATE_1    VALUE_x
# 10420 2015-01-01   6907.950
# 10460 2015-01-01      0.000
# 10459 2015-01-01      0.000
# 10458 2015-01-01    113.400
# 10457 2015-01-01      0.000
# ...          ...        ...
# 13232 2018-12-01      0.000
# 13231 2018-12-01    506.520
# 13230 2018-12-01  16217.145
# 13228 2018-12-01    176.445
# 13217 2018-12-01   5363.280
#
# [3668 rows x 2 columns]

# %%
df1['DATE_1'].min(), df1['DATE_1'].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2018-12-01 00:00:00'))

# %%
df1.head()
# Out:
#       DATE_1     VALUE_x
# 0 2015-01-01  109526.175
# 1 2015-02-01  118257.165
# 2 2015-03-01   45239.580
# 3 2015-04-01  181633.185
# 4 2015-05-01  184528.935

# %%
df1["DATE_1"].value_counts()
# Out:
# 2015-01-01    1
# 2017-11-01    1
# 2017-02-01    1
# 2017-03-01    1
# 2017-04-01    1
# 2017-05-01    1
# 2017-06-01    1
# 2017-07-01    1
# 2017-08-01    1
# 2017-09-01    1
# 2017-10-01    1
# 2017-12-01    1
# 2015-02-01    1
# 2018-01-01    1
# 2018-04-01    1
# 2018-05-01    1
# 2018-06-01    1
# 2018-07-01    1
# 2018-08-01    1
# 2018-09-01    1
# 2018-10-01    1
# 2018-11-01    1
# 2017-01-01    1
# 2016-12-01    1
# 2016-11-01    1
# 2016-10-01    1
# 2015-03-01    1
# 2015-04-01    1
# 2015-05-01    1
# 2015-06-01    1
# 2015-07-01    1
# 2015-08-01    1
# 2015-09-01    1
# 2015-10-01    1
# 2015-11-01    1
# 2015-12-01    1
# 2016-01-01    1
# 2016-02-01    1
# 2016-03-01    1
# 2016-04-01    1
# 2016-05-01    1
# 2016-06-01    1
# 2016-07-01    1
# 2016-08-01    1
# 2016-09-01    1
# 2018-12-01    1
# Name: DATE_1, dtype: int64

# %%
df1.dtypes
# Out:
# DATE_1     datetime64[ns]
# VALUE_x           float64
# dtype: object

# %%
df1 = df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1.head(10)
# Out:
#       DATE_1     VALUE_x
# 0 2015-01-01  109526.175
# 1 2015-02-01  118257.165
# 2 2015-03-01   45239.580
# 3 2015-04-01  181633.185
# 4 2015-05-01  184528.935
# 5 2015-06-01  151493.085
# 6 2015-07-01   99722.475
# 7 2015-08-01  149691.915
# 8 2015-09-01  115486.965
# 9 2015-10-01  305785.800

# %%
df1["DATE_1"].value_counts()
# Out:
# 2015-01-01    1
# 2017-11-01    1
# 2017-02-01    1
# 2017-03-01    1
# 2017-04-01    1
# 2017-05-01    1
# 2017-06-01    1
# 2017-07-01    1
# 2017-08-01    1
# 2017-09-01    1
# 2017-10-01    1
# 2017-12-01    1
# 2015-02-01    1
# 2018-01-01    1
# 2018-04-01    1
# 2018-05-01    1
# 2018-06-01    1
# 2018-07-01    1
# 2018-08-01    1
# 2018-09-01    1
# 2018-10-01    1
# 2018-11-01    1
# 2017-01-01    1
# 2016-12-01    1
# 2016-11-01    1
# 2016-10-01    1
# 2015-03-01    1
# 2015-04-01    1
# 2015-05-01    1
# 2015-06-01    1
# 2015-07-01    1
# 2015-08-01    1
# 2015-09-01    1
# 2015-10-01    1
# 2015-11-01    1
# 2015-12-01    1
# 2016-01-01    1
# 2016-02-01    1
# 2016-03-01    1
# 2016-04-01    1
# 2016-05-01    1
# 2016-06-01    1
# 2016-07-01    1
# 2016-08-01    1
# 2016-09-01    1
# 2018-12-01    1
# Name: DATE_1, dtype: int64

# %%
df1 = df1.groupby('DATE_1')["VALUE_x"].sum().reset_index()
df1.shape
# Out:
# (46, 2)

# %%
df1.head(10)
# Out:
#       DATE_1     VALUE_x
# 0 2015-01-01  109526.175
# 1 2015-02-01  118257.165
# 2 2015-03-01   45239.580
# 3 2015-04-01  181633.185
# 4 2015-05-01  184528.935
# 5 2015-06-01  151493.085
# 6 2015-07-01   99722.475
# 7 2015-08-01  149691.915
# 8 2015-09-01  115486.965
# 9 2015-10-01  305785.800

# %%
df1 = df1.set_index("DATE_1")

# %%
df1.head(10)
# Out:
#                VALUE_x
# DATE_1
# 2015-01-01  109526.175
# 2015-02-01  118257.165
# 2015-03-01   45239.580
# 2015-04-01  181633.185
# 2015-05-01  184528.935
# 2015-06-01  151493.085
# 2015-07-01   99722.475
# 2015-08-01  149691.915
# 2015-09-01  115486.965
# 2015-10-01  305785.800

# %%
df1.dtypes
# Out:
# VALUE_x    float64
# dtype: object

# %%
y = df1['VALUE_x'].resample('M').sum()

# %%
y
# Out:
# DATE_1
# 2015-01-31    109526.175
# 2015-02-28    118257.165
# 2015-03-31     45239.580
# 2015-04-30    181633.185
# 2015-05-31    184528.935
# 2015-06-30    151493.085
# 2015-07-31     99722.475
# 2015-08-31    149691.915
# 2015-09-30    115486.965
# 2015-10-31    305785.800
# 2015-11-30    183920.490
# 2015-12-31    198224.280
# 2016-01-31    253721.835
# 2016-02-29    104799.285
# 2016-03-31    228154.725
# 2016-04-30    291320.955
# 2016-05-31    399479.040
# 2016-06-30    182901.105
# 2016-07-31    162270.135
# 2016-08-31    188838.945
# 2016-09-30    193174.470
# 2016-10-31    426452.310
# 2016-11-30    150497.730
# 2016-12-31    183275.190
# 2017-01-31     61821.630
# 2017-02-28    152025.525
# 2017-03-31    216319.815
# 2017-04-30     44783.685
# 2017-05-31    107567.190
# 2017-06-30    166298.940
# 2017-07-31    135769.500
# 2017-08-31    269317.980
# 2017-09-30    157380.570
# 2017-10-31    208027.170
# 2017-11-30    220494.015
# 2017-12-31    202958.730
# 2018-01-31     93745.890
# 2018-02-28         0.000
# 2018-03-31         0.000
# 2018-04-30     54139.320
# 2018-05-31    127212.660
# 2018-06-30    159290.145
# 2018-07-31     98945.145
# 2018-08-31    198493.335
# 2018-09-30    162217.890
# 2018-10-31    248477.085
# 2018-11-30    234001.035
# 2018-12-31    148460.850
# Freq: M, Name: VALUE_x, dtype: float64

# %%
print(y.shape)
# Out:
# (48,)

# %%
y.isnull().sum()
# Out:
# 0

# %%
y.plot(figsize=(20,8))
plt.show()

# %%
train = y.loc[:'2017-08-31']
print(train.shape)
train
# Out:
# (32,)
# DATE_1
# 2015-01-31    109526.175
# 2015-02-28    118257.165
# 2015-03-31     45239.580
# 2015-04-30    181633.185
# 2015-05-31    184528.935
# 2015-06-30    151493.085
# 2015-07-31     99722.475
# 2015-08-31    149691.915
# 2015-09-30    115486.965
# 2015-10-31    305785.800
# 2015-11-30    183920.490
# 2015-12-31    198224.280
# 2016-01-31    253721.835
# 2016-02-29    104799.285
# 2016-03-31    228154.725
# 2016-04-30    291320.955
# 2016-05-31    399479.040
# 2016-06-30    182901.105
# 2016-07-31    162270.135
# 2016-08-31    188838.945
# 2016-09-30    193174.470
# 2016-10-31    426452.310
# 2016-11-30    150497.730
# 2016-12-31    183275.190
# 2017-01-31     61821.630
# 2017-02-28    152025.525
# 2017-03-31    216319.815
# 2017-04-30     44783.685
# 2017-05-31    107567.190
# 2017-06-30    166298.940
# 2017-07-31    135769.500
# 2017-08-31    269317.980
# Freq: M, Name: VALUE_x, dtype: float64

# %%
test = y.loc['2017-09-30':]
print(test.shape)
test
# Out:
# (16,)
# DATE_1
# 2017-09-30    157380.570
# 2017-10-31    208027.170
# 2017-11-30    220494.015
# 2017-12-31    202958.730
# 2018-01-31     93745.890
# 2018-02-28         0.000
# 2018-03-31         0.000
# 2018-04-30     54139.320
# 2018-05-31    127212.660
# 2018-06-30    159290.145
# 2018-07-31     98945.145
# 2018-08-31    198493.335
# 2018-09-30    162217.890
# 2018-10-31    248477.085
# 2018-11-30    234001.035
# 2018-12-31    148460.850
# Freq: M, Name: VALUE_x, dtype: float64

# %%
train.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
test.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
plt.show()

# %%
#determining rolling statistics (rolling mean at yearly level window=12)
rolmean=company1.rolling(window=12).mean()


print(rolmean)
# Out:
#                  VALUE_x
# DATE_1
# 2015-01-01           NaN
# 2015-02-01           NaN
# 2015-03-01           NaN
# 2015-04-01           NaN
# 2015-05-01           NaN
# 2015-06-01           NaN
# 2015-07-01           NaN
# 2015-08-01           NaN
# 2015-09-01           NaN
# 2015-10-01           NaN
# 2015-11-01           NaN
# 2015-12-01  153625.83750
# 2016-01-01  165642.14250
# 2016-02-01  164520.65250
# 2016-03-01  179763.58125
# 2016-04-01  188904.22875
# 2016-05-01  206816.73750
# 2016-06-01  209434.07250
# 2016-07-01  214646.37750
# 2016-08-01  217908.63000
# 2016-09-01  224382.58875
# 2016-10-01  234438.13125
# 2016-11-01  231652.90125
# 2016-12-01  230407.14375
# 2017-01-01  214415.46000
# 2017-02-01  218350.98000
# 2017-03-01  217364.73750
# 2017-04-01  196819.96500
# 2017-05-01  172493.97750
# 2017-06-01  171110.46375
# 2017-07-01  168902.07750
# 2017-08-01  175608.66375
# 2017-09-01  172625.83875
# 2017-10-01  154423.74375
# 2017-11-01  160256.76750
# 2017-12-01  161897.06250
# 2018-01-01  164557.41750
# 2018-04-01  156400.23375
# 2018-05-01  148974.63750
# 2018-06-01  158516.84250
# 2018-07-01  157798.33875
# 2018-08-01  160481.20500
# 2018-09-01  162685.23750
# 2018-10-01  160948.49625
# 2018-11-01  167333.53500
# 2018-12-01  162369.67500

# %%
rolstd=company1.rolling(window=12).std()
print(rolstd)
# Out:
#                   VALUE_x
# DATE_1
# 2015-01-01            NaN
# 2015-02-01            NaN
# 2015-03-01            NaN
# 2015-04-01            NaN
# 2015-05-01            NaN
# 2015-06-01            NaN
# 2015-07-01            NaN
# 2015-08-01            NaN
# 2015-09-01            NaN
# 2015-10-01            NaN
# 2015-11-01            NaN
# 2015-12-01   65451.112003
# 2016-01-01   69716.346159
# 2016-02-01   70649.893828
# 2016-03-01   61746.285042
# 2016-04-01   69659.937528
# 2016-05-01   92367.786672
# 2016-06-01   91093.824660
# 2016-07-01   85886.139583
# 2016-08-01   83915.516267
# 2016-09-01   78090.034331
# 2016-10-01   95380.058095
# 2016-11-01   97454.781643
# 2016-12-01   98014.881246
# 2017-01-01  108913.969231
# 2017-02-01  105389.199889
# 2017-03-01  105344.481717
# 2017-04-01  113346.493534
# 2017-05-01   95876.822828
# 2017-06-01   95832.769862
# 2017-07-01   96358.905916
# 2017-08-01  100580.841047
# 2017-09-01  100543.297030
# 2017-10-01   63280.100242
# 2017-11-01   66050.709940
# 2017-12-01   66913.092981
# 2018-01-01   63098.438529
# 2018-04-01   70731.357684
# 2018-05-01   68511.484801
# 2018-06-01   60143.820089
# 2018-07-01   60855.114915
# 2018-08-01   61963.511526
# 2018-09-01   61473.053200
# 2018-10-01   58404.391996
# 2018-11-01   62053.145647
# 2018-12-01   60873.228305

# %%
#plotting rolling statistics (Rolling Mean)
orig=plt.plot(y,color='blue',label="Original")
mean=plt.plot(rolmean,color='red',label='Rolling Mean')
#std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Rolling Mean ")
plt.show(block=True)

# %%
#plotting rolling statistics(Rolling Deviation)
orig=plt.plot(y,color='blue',label="Original")
#mean=plt.plot(rolmean,color='red',label='Rolling Mean')
std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Standard Deviation")
plt.show(block=False)

# %%
#ADFULLER test
from statsmodels.tsa.stattools import adfuller
print("ADfuller test")
dftest = adfuller(y,autolag ='AIC')
dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','number of observations used'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)'%key]= value
print(dfoutput)

# # we reject null hypothesis : It is Stationary
# Out:
# ADfuller test
# Test Statistic                 -4.922060
# p-value                         0.000032
# #lags used                      0.000000
# number of observations used    47.000000
# critical value (1%)            -3.577848
# critical value (5%)            -2.925338
# critical value (10%)           -2.600774
# dtype: float64

# %%
#Simple ExpSmoothening
from statsmodels.tsa.api import SimpleExpSmoothing
Exp_Smooth = test.copy()
fit1 = SimpleExpSmoothing(train).fit(smoothing_level=0.01)
Exp_Smooth['SES'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Exp_Smooth['SES'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Exp_Smooth.SES
# Out:
# 2017-09-30    180102.830848
# 2017-10-31    180102.830848
# 2017-11-30    180102.830848
# 2017-12-31    180102.830848
# 2018-01-31    180102.830848
# 2018-02-28    180102.830848
# 2018-03-31    180102.830848
# 2018-04-30    180102.830848
# 2018-05-31    180102.830848
# 2018-06-30    180102.830848
# 2018-07-31    180102.830848
# 2018-08-31    180102.830848
# 2018-09-30    180102.830848
# 2018-10-31    180102.830848
# 2018-11-30    180102.830848
# 2018-12-31    180102.830848
# Freq: M, dtype: float64

# %%
fit1.aic
# Out:
# 732.099371702582

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Exp_Smooth.SES))
print(rmse)
# Out:
# 83180.81065430611

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(y)
fig = decomposition.plot()
plt.show()

# %%
# Double ExpSmoothening
from statsmodels.tsa.api import Holt
Holt_df = test.copy()
#soothing slope = beta
fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
Holt_df['Holt_linear'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_df['Holt_linear'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\AppData\Local\Temp/ipykernel_17432/527924908.py:5: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 740.1832821674699

# %%
Holt_df['Holt_linear']
# Out:
# 2017-09-30    77896.675154
# 2017-10-31    78423.290130
# 2017-11-30    78949.905106
# 2017-12-31    79476.520081
# 2018-01-31    80003.135057
# 2018-02-28    80529.750033
# 2018-03-31    81056.365009
# 2018-04-30    81582.979985
# 2018-05-31    82109.594960
# 2018-06-30    82636.209936
# 2018-07-31    83162.824912
# 2018-08-31    83689.439888
# 2018-09-30    84216.054863
# 2018-10-31    84742.669839
# 2018-11-30    85269.284815
# 2018-12-31    85795.899791
# Freq: M, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_df['Holt_linear']))
print(rmse)
# Out:
# 97684.13441183188

# %%
#Triple ExpSmoothening
from statsmodels.tsa.api import ExponentialSmoothing
Holt_Winter_df = test.copy()
#soothing slope = beta
fit1 = ExponentialSmoothing(train,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Holt_Winter_df['Holt_Winter'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_Winter_df['Holt_Winter'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 754.0077159696992

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_Winter_df['Holt_Winter']))
print(rmse)
# Out:
# 116434.4456708253

# %%
Holt_Winter_df['Holt_Winter']
# Out:
# 2017-09-30    165586.022772
# 2017-10-31    359839.248391
# 2017-11-30    241907.413304
# 2017-12-31    260166.838779
# 2018-01-31    175431.519935
# 2018-02-28    188102.904715
# 2018-03-31    119069.563907
# 2018-04-30    259365.988788
# 2018-05-31    266232.944165
# 2018-06-30    237136.565884
# 2018-07-31    189322.990021
# 2018-08-31    243237.982612
# 2018-09-30    212988.465008
# 2018-10-31    407241.690627
# 2018-11-30    289309.855540
# 2018-12-31    307569.281015
# Freq: M, dtype: float64

# %%
from statsmodels.tsa.api import ExponentialSmoothing


fit1 = ExponentialSmoothing(y,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Y_predictions = fit1.forecast(steps=12)

y.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)

Y_predictions.plot(figsize=(10,6), title= 'Average Sales', fontsize=14) 
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Y_predictions
# Out:
# 2019-01-31     96835.084798
# 2019-02-28    105038.081931
# 2019-03-31     31556.062079
# 2019-04-30    167386.603530
# 2019-05-31    169803.167172
# 2019-06-30    136254.362107
# 2019-07-31     83978.842194
# 2019-08-31    133448.881912
# 2019-09-30     98726.819858
# 2019-10-31    288494.569288
# 2019-11-30    166132.808569
# 2019-12-31    179921.968444
# Freq: M, dtype: float64

# %%
train.plot(figsize=(20,8), title= 'Train - Average Sales ', fontsize=14,color="black",legend=True,label="Train Average Sales")
test.plot(figsize=(20,8), title='Test - Average Sales', fontsize=14,color="grey",legend=True,label="Test Average Sales")
Exp_Smooth['SES'].plot(figsize=(20,8),  fontsize=14,color="red",legend=True,label="Simple Exponential Smoothing")                                  
Holt_df['Holt_linear'].plot(figsize=(20,8),  fontsize=14,color="green",legend=True,label="Holt Linear")                                  
Holt_Winter_df['Holt_Winter'].plot(figsize=(20,8),  fontsize=14,color="blue",legend=True,label="Holt Winter") # seems Triple smooethening
Y_predictions.plot(figsize=(10,6),  fontsize=14,color="purple",legend=True,label="Predictions") 
plt.show() 
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# # ARIMA MODEL

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(y,start_p=0, max_p=3, d=None, max_d=2,start_q=0, max_q=3,  
                      start_P=0,max_P=3, D=None, max_D=2, start_Q=0, max_Q=3,
                      max_order=10, m=12, seasonal=True, information_criterion='aic',
                      test='adf',trace=True,random_state=10)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1220.248, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1214.748, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1209.148, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1218.261, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1208.662, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1209.081, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1211.075, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1209.949, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1211.131, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1213.607, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1212.564, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=1206.883, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=1207.280, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=1207.376, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=1209.200, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=1207.958, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=1209.164, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=1211.646, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=1210.766, Time=0.03 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12]
# Total fit time: 0.581 seconds

# %%
model
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
model.aic()
# Out:
# 1206.883284484132

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model =SARIMAX(y, order=(0,1,1), seasonal_order=(0,0,2,12)).fit()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
Y_pred = pred.predicted_mean
Y_test = y['2018-01-01':]
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(Y_test,Y_pred))
print(rmse)
# Out:
# 72515.70841476507

# %%
#pred = model.get_prediction(start=pd.to_datetime('2017-01-31')) 
pred = model.get_forecast(steps=12)

plt.figure(figsize=(10,6))
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Validation Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
pred.predicted_mean
# Out:
# 2019-01-31    154198.115044
# 2019-02-28    141024.134001
# 2019-03-31    140338.762849
# 2019-04-30    145238.247985
# 2019-05-31    159515.200734
# 2019-06-30    171721.336034
# 2019-07-31    159114.401786
# 2019-08-31    182379.854242
# 2019-09-30    171774.721216
# 2019-10-31    186291.691485
# 2019-11-30    188858.527515
# 2019-12-31    170639.671811
# Freq: M, Name: predicted_mean, dtype: float64

# %%
#pred.predicted_mean.to_excel("Timeseriesoutput.xlsx",index=True)

# %% [markdown]
# # State of Haryana

# %%
df.head(10)
# Out:
#     FIN_YEAR MONTH    STATE            FG     DISTRICT            COMPANY  \
# 0  2014-2015   May  Haryana  Insecticides       Ambala  ABC Manufacturing
# 1  2014-2015   May  Haryana  Insecticides  Yamunanagar  ABC Manufacturing
# 2  2014-2015   May  Haryana  Insecticides  Kurukshetra  ABC Manufacturing
# 3  2014-2015   May  Haryana  Insecticides       Karnal  ABC Manufacturing
# 4  2014-2015   May  Haryana  Insecticides      Panipat  ABC Manufacturing
# 5  2014-2015   May  Haryana  Insecticides         Jind  ABC Manufacturing
# 6  2014-2015   May  Haryana  Insecticides    Fatehabad  ABC Manufacturing
# 7  2014-2015   May  Haryana  Insecticides        Hisar  ABC Manufacturing
# 8  2014-2015   May  Haryana  Insecticides      Bhiwani  ABC Manufacturing
# 9  2014-2015   May  Haryana  Insecticides       Rohtak  ABC Manufacturing
#
#     VALUE_x     DATE_1  Rainfall in  mm     DATE_2 month_full    Year  \
# 0   252.720 2015-05-01             20.5 2014-05-01        May  2014.0
# 1   933.255 2015-05-01             26.8 2014-05-01        May  2014.0
# 2  2675.430 2015-05-01              4.2 2014-05-01        May  2014.0
# 3  3436.830 2015-05-01             29.7 2014-05-01        May  2014.0
# 4   472.770 2015-05-01             21.5 2014-05-01        May  2014.0
# 5  8360.415 2015-05-01             48.5 2014-05-01        May  2014.0
# 6  3989.520 2015-05-01              8.6 2014-05-01        May  2014.0
# 7  3356.910 2015-05-01             25.2 2014-05-01        May  2014.0
# 8  1738.935 2015-05-01             27.2 2014-05-01        May  2014.0
# 9   315.360 2015-05-01             11.4 2014-05-01        May  2014.0
#
#   As Quarter  Fiscal Year
# 0     2015Q1       2015.0
# 1     2015Q1       2015.0
# 2     2015Q1       2015.0
# 3     2015Q1       2015.0
# 4     2015Q1       2015.0
# 5     2015Q1       2015.0
# 6     2015Q1       2015.0
# 7     2015Q1       2015.0
# 8     2015Q1       2015.0
# 9     2015Q1       2015.0

# %%
df["STATE"].value_counts()
# Out:
# Uttar Pradesh       13024
# Haryana              6028
# Himachal Pradesh     3880
# Punjab               3668
# Uttarakhand          2040
# Name: STATE, dtype: int64

# %%
state =  df[df['STATE']=='Haryana']

# %%
state.shape
# Out:
# (6028, 14)

# %%
state
# Out:
#        FIN_YEAR MONTH    STATE            FG     DISTRICT            COMPANY  \
# 0     2014-2015   May  Haryana  Insecticides       Ambala  ABC Manufacturing
# 1     2014-2015   May  Haryana  Insecticides  Yamunanagar  ABC Manufacturing
# 2     2014-2015   May  Haryana  Insecticides  Kurukshetra  ABC Manufacturing
# 3     2014-2015   May  Haryana  Insecticides       Karnal  ABC Manufacturing
# 4     2014-2015   May  Haryana  Insecticides      Panipat  ABC Manufacturing
# ...         ...   ...      ...           ...          ...                ...
# 6023  2017-2018   Apr  Haryana  Bactericides      Kaithal  ABC Manufacturing
# 6024  2017-2018   Apr  Haryana  Bactericides       Rohtak  ABC Manufacturing
# 6025  2017-2018   Apr  Haryana  Bactericides       Ambala  ABC Manufacturing
# 6026  2017-2018   Apr  Haryana  Bactericides         Jind  ABC Manufacturing
# 6027  2017-2018   Apr  Haryana  Bactericides      Jhajjar  ABC Manufacturing
#
#        VALUE_x     DATE_1  Rainfall in  mm     DATE_2 month_full    Year  \
# 0      252.720 2015-05-01             20.5 2014-05-01        May  2014.0
# 1      933.255 2015-05-01             26.8 2014-05-01        May  2014.0
# 2     2675.430 2015-05-01              4.2 2014-05-01        May  2014.0
# 3     3436.830 2015-05-01             29.7 2014-05-01        May  2014.0
# 4      472.770 2015-05-01             21.5 2014-05-01        May  2014.0
# ...        ...        ...              ...        ...        ...     ...
# 6023     0.000 2018-04-01             21.5 2018-04-01      April  2018.0
# 6024     0.000 2018-04-01              6.7 2018-04-01      April  2018.0
# 6025     0.000 2018-04-01              7.1 2018-04-01      April  2018.0
# 6026     0.000 2018-04-01              4.3 2018-04-01      April  2018.0
# 6027     0.000 2018-04-01              8.8 2018-04-01      April  2018.0
#
#      As Quarter  Fiscal Year
# 0        2015Q1       2015.0
# 1        2015Q1       2015.0
# 2        2015Q1       2015.0
# 3        2015Q1       2015.0
# 4        2015Q1       2015.0
# ...         ...          ...
# 6023     2019Q1       2019.0
# 6024     2019Q1       2019.0
# 6025     2019Q1       2019.0
# 6026     2019Q1       2019.0
# 6027     2019Q1       2019.0
#
# [6028 rows x 14 columns]

# %%
df1 =state[['DATE_1','VALUE_x']]

# %%
df1= df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1
# Out:
#          DATE_1   VALUE_x
# 683  2015-01-01     0.270
# 702  2015-01-01     0.000
# 701  2015-01-01     2.295
# 700  2015-01-01     8.505
# 699  2015-01-01     0.000
# ...         ...       ...
# 5805 2018-12-01     2.160
# 5804 2018-12-01    25.380
# 5803 2018-12-01     6.750
# 5801 2018-12-01     0.000
# 5781 2018-12-01  3671.460
#
# [6028 rows x 2 columns]

# %%
df1['DATE_1'].min(), df1['DATE_1'].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2018-12-01 00:00:00'))

# %%
df1.head()
# Out:
#         DATE_1  VALUE_x
# 683 2015-01-01    0.270
# 702 2015-01-01    0.000
# 701 2015-01-01    2.295
# 700 2015-01-01    8.505
# 699 2015-01-01    0.000

# %%
df1["DATE_1"].value_counts()
# Out:
# 2017-10-01    328
# 2017-12-01    328
# 2017-11-01    316
# 2017-09-01    300
# 2017-08-01    284
# 2017-06-01    280
# 2017-01-01    276
# 2017-07-01    272
# 2017-03-01    256
# 2017-02-01    240
# 2017-05-01    212
# 2017-04-01    168
# 2016-12-01     84
# 2016-11-01     84
# 2018-01-01     84
# 2018-05-01     84
# 2018-07-01     84
# 2018-08-01     84
# 2018-10-01     84
# 2018-11-01     84
# 2015-02-01     84
# 2018-12-01     84
# 2016-10-01     84
# 2016-03-01     84
# 2015-04-01     84
# 2015-06-01     84
# 2015-09-01     84
# 2016-09-01     84
# 2015-10-01     84
# 2016-04-01     84
# 2016-08-01     84
# 2016-05-01     84
# 2015-08-01     80
# 2016-07-01     80
# 2016-02-01     80
# 2018-04-01     80
# 2016-06-01     80
# 2015-11-01     80
# 2015-12-01     80
# 2015-01-01     80
# 2015-07-01     76
# 2018-06-01     76
# 2015-05-01     76
# 2018-09-01     76
# 2016-01-01     72
# 2015-03-01     72
# Name: DATE_1, dtype: int64

# %%
df1.dtypes
# Out:
# DATE_1     datetime64[ns]
# VALUE_x           float64
# dtype: object

# %%
df1 = df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1.head(10)
# Out:
#         DATE_1    VALUE_x
# 683 2015-01-01      0.270
# 653 2015-01-01  15496.920
# 646 2015-01-01   1479.060
# 647 2015-01-01   6698.970
# 648 2015-01-01  13089.735
# 649 2015-01-01   8706.150
# 650 2015-01-01   7803.000
# 651 2015-01-01  15169.545
# 684 2015-01-01     17.280
# 652 2015-01-01   7411.635

# %%
df1 = df1.groupby('DATE_1')["VALUE_x"].sum().reset_index()
df1.shape
# Out:
# (46, 2)

# %%
df1.head(10)
# Out:
#       DATE_1     VALUE_x
# 0 2015-01-01  128078.820
# 1 2015-02-01  107427.060
# 2 2015-03-01  110342.925
# 3 2015-04-01   32577.660
# 4 2015-05-01   47482.740
# 5 2015-06-01  130684.185
# 6 2015-07-01   75471.075
# 7 2015-08-01  107146.530
# 8 2015-09-01  138232.710
# 9 2015-10-01  168045.030

# %%
df1 = df1.set_index("DATE_1")

# %%
df1.head(10)
# Out:
#                VALUE_x
# DATE_1
# 2015-01-01  128078.820
# 2015-02-01  107427.060
# 2015-03-01  110342.925
# 2015-04-01   32577.660
# 2015-05-01   47482.740
# 2015-06-01  130684.185
# 2015-07-01   75471.075
# 2015-08-01  107146.530
# 2015-09-01  138232.710
# 2015-10-01  168045.030

# %%
df1.dtypes
# Out:
# VALUE_x    float64
# dtype: object

# %%
y = df1['VALUE_x'].resample('M').sum()

# %%
y
# Out:
# DATE_1
# 2015-01-31    128078.820
# 2015-02-28    107427.060
# 2015-03-31    110342.925
# 2015-04-30     32577.660
# 2015-05-31     47482.740
# 2015-06-30    130684.185
# 2015-07-31     75471.075
# 2015-08-31    107146.530
# 2015-09-30    138232.710
# 2015-10-31    168045.030
# 2015-11-30    175710.870
# 2015-12-31    127656.945
# 2016-01-31     75341.880
# 2016-02-29     73139.760
# 2016-03-31    106902.720
# 2016-04-30    131720.580
# 2016-05-31    149968.395
# 2016-06-30    160265.790
# 2016-07-31    132693.660
# 2016-08-31    129301.785
# 2016-09-30    137774.115
# 2016-10-31    313321.500
# 2016-11-30    163620.135
# 2016-12-31    152072.100
# 2017-01-31     84634.065
# 2017-02-28     58354.155
# 2017-03-31    115689.195
# 2017-04-30     16131.285
# 2017-05-31     63360.630
# 2017-06-30    144712.575
# 2017-07-31    114598.395
# 2017-08-31    100687.320
# 2017-09-30    202416.975
# 2017-10-31    120286.890
# 2017-11-30    154636.020
# 2017-12-31    156926.565
# 2018-01-31    145582.245
# 2018-02-28         0.000
# 2018-03-31         0.000
# 2018-04-30     11309.085
# 2018-05-31    110724.975
# 2018-06-30    171017.595
# 2018-07-31     97934.940
# 2018-08-31     80357.130
# 2018-09-30     92884.995
# 2018-10-31    135560.655
# 2018-11-30    213711.210
# 2018-12-31    200733.525
# Freq: M, Name: VALUE_x, dtype: float64

# %%
print(y.shape)
# Out:
# (48,)

# %%
y.isnull().sum()
# Out:
# 0

# %%
y.plot(figsize=(20,8))
plt.show()

# %%
train = y.loc[:'2017-08-31']
print(train.shape)
train
# Out:
# (32,)
# DATE_1
# 2015-01-31    128078.820
# 2015-02-28    107427.060
# 2015-03-31    110342.925
# 2015-04-30     32577.660
# 2015-05-31     47482.740
# 2015-06-30    130684.185
# 2015-07-31     75471.075
# 2015-08-31    107146.530
# 2015-09-30    138232.710
# 2015-10-31    168045.030
# 2015-11-30    175710.870
# 2015-12-31    127656.945
# 2016-01-31     75341.880
# 2016-02-29     73139.760
# 2016-03-31    106902.720
# 2016-04-30    131720.580
# 2016-05-31    149968.395
# 2016-06-30    160265.790
# 2016-07-31    132693.660
# 2016-08-31    129301.785
# 2016-09-30    137774.115
# 2016-10-31    313321.500
# 2016-11-30    163620.135
# 2016-12-31    152072.100
# 2017-01-31     84634.065
# 2017-02-28     58354.155
# 2017-03-31    115689.195
# 2017-04-30     16131.285
# 2017-05-31     63360.630
# 2017-06-30    144712.575
# 2017-07-31    114598.395
# 2017-08-31    100687.320
# Freq: M, Name: VALUE_x, dtype: float64

# %%
test = y.loc['2017-09-30':]
print(test.shape)
test
# Out:
# (16,)
# DATE_1
# 2017-09-30    202416.975
# 2017-10-31    120286.890
# 2017-11-30    154636.020
# 2017-12-31    156926.565
# 2018-01-31    145582.245
# 2018-02-28         0.000
# 2018-03-31         0.000
# 2018-04-30     11309.085
# 2018-05-31    110724.975
# 2018-06-30    171017.595
# 2018-07-31     97934.940
# 2018-08-31     80357.130
# 2018-09-30     92884.995
# 2018-10-31    135560.655
# 2018-11-30    213711.210
# 2018-12-31    200733.525
# Freq: M, Name: VALUE_x, dtype: float64

# %%
train.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
test.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
plt.show()

# %%
#determining rolling statistics (rolling mean at yearly level window=12)
rolmean=company1.rolling(window=12).mean()


print(rolmean)
# Out:
#                  VALUE_x
# DATE_1
# 2015-01-01           NaN
# 2015-02-01           NaN
# 2015-03-01           NaN
# 2015-04-01           NaN
# 2015-05-01           NaN
# 2015-06-01           NaN
# 2015-07-01           NaN
# 2015-08-01           NaN
# 2015-09-01           NaN
# 2015-10-01           NaN
# 2015-11-01           NaN
# 2015-12-01  153625.83750
# 2016-01-01  165642.14250
# 2016-02-01  164520.65250
# 2016-03-01  179763.58125
# 2016-04-01  188904.22875
# 2016-05-01  206816.73750
# 2016-06-01  209434.07250
# 2016-07-01  214646.37750
# 2016-08-01  217908.63000
# 2016-09-01  224382.58875
# 2016-10-01  234438.13125
# 2016-11-01  231652.90125
# 2016-12-01  230407.14375
# 2017-01-01  214415.46000
# 2017-02-01  218350.98000
# 2017-03-01  217364.73750
# 2017-04-01  196819.96500
# 2017-05-01  172493.97750
# 2017-06-01  171110.46375
# 2017-07-01  168902.07750
# 2017-08-01  175608.66375
# 2017-09-01  172625.83875
# 2017-10-01  154423.74375
# 2017-11-01  160256.76750
# 2017-12-01  161897.06250
# 2018-01-01  164557.41750
# 2018-04-01  156400.23375
# 2018-05-01  148974.63750
# 2018-06-01  158516.84250
# 2018-07-01  157798.33875
# 2018-08-01  160481.20500
# 2018-09-01  162685.23750
# 2018-10-01  160948.49625
# 2018-11-01  167333.53500
# 2018-12-01  162369.67500

# %%
rolstd=company1.rolling(window=12).std()
print(rolstd)
# Out:
#                   VALUE_x
# DATE_1
# 2015-01-01            NaN
# 2015-02-01            NaN
# 2015-03-01            NaN
# 2015-04-01            NaN
# 2015-05-01            NaN
# 2015-06-01            NaN
# 2015-07-01            NaN
# 2015-08-01            NaN
# 2015-09-01            NaN
# 2015-10-01            NaN
# 2015-11-01            NaN
# 2015-12-01   65451.112003
# 2016-01-01   69716.346159
# 2016-02-01   70649.893828
# 2016-03-01   61746.285042
# 2016-04-01   69659.937528
# 2016-05-01   92367.786672
# 2016-06-01   91093.824660
# 2016-07-01   85886.139583
# 2016-08-01   83915.516267
# 2016-09-01   78090.034331
# 2016-10-01   95380.058095
# 2016-11-01   97454.781643
# 2016-12-01   98014.881246
# 2017-01-01  108913.969231
# 2017-02-01  105389.199889
# 2017-03-01  105344.481717
# 2017-04-01  113346.493534
# 2017-05-01   95876.822828
# 2017-06-01   95832.769862
# 2017-07-01   96358.905916
# 2017-08-01  100580.841047
# 2017-09-01  100543.297030
# 2017-10-01   63280.100242
# 2017-11-01   66050.709940
# 2017-12-01   66913.092981
# 2018-01-01   63098.438529
# 2018-04-01   70731.357684
# 2018-05-01   68511.484801
# 2018-06-01   60143.820089
# 2018-07-01   60855.114915
# 2018-08-01   61963.511526
# 2018-09-01   61473.053200
# 2018-10-01   58404.391996
# 2018-11-01   62053.145647
# 2018-12-01   60873.228305

# %%
#plotting rolling statistics (Rolling Mean)
orig=plt.plot(y,color='blue',label="Original")
mean=plt.plot(rolmean,color='red',label='Rolling Mean')
#std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Rolling Mean ")
plt.show(block=True)

# %%
#plotting rolling statistics(Rolling Deviation)
orig=plt.plot(y,color='blue',label="Original")
#mean=plt.plot(rolmean,color='red',label='Rolling Mean')
std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Standard Deviation")
plt.show(block=False)

# %%
#ADFULLER test
from statsmodels.tsa.stattools import adfuller
print("ADfuller test")
dftest = adfuller(y,autolag ='AIC')
dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','number of observations used'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)'%key]= value
print(dfoutput)

# # we reject null hypothesis : It is Stationary
# Out:
# ADfuller test
# Test Statistic                 -4.028323
# p-value                         0.001269
# #lags used                      0.000000
# number of observations used    47.000000
# critical value (1%)            -3.577848
# critical value (5%)            -2.925338
# critical value (10%)           -2.600774
# dtype: float64

# %%
#Simple ExpSmoothening
from statsmodels.tsa.api import SimpleExpSmoothing
Exp_Smooth = test.copy()
fit1 = SimpleExpSmoothing(train).fit(smoothing_level=0.01)
Exp_Smooth['SES'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Exp_Smooth['SES'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Exp_Smooth.SES
# Out:
# 2017-09-30    117908.303179
# 2017-10-31    117908.303179
# 2017-11-30    117908.303179
# 2017-12-31    117908.303179
# 2018-01-31    117908.303179
# 2018-02-28    117908.303179
# 2018-03-31    117908.303179
# 2018-04-30    117908.303179
# 2018-05-31    117908.303179
# 2018-06-30    117908.303179
# 2018-07-31    117908.303179
# 2018-08-31    117908.303179
# 2018-09-30    117908.303179
# 2018-10-31    117908.303179
# 2018-11-30    117908.303179
# 2018-12-31    117908.303179
# Freq: M, dtype: float64

# %%
fit1.aic
# Out:
# 700.2188448787886

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Exp_Smooth.SES))
print(rmse)
# Out:
# 66900.06924667243

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(y)
fig = decomposition.plot()
plt.show()

# %%
# Double ExpSmoothening
from statsmodels.tsa.api import Holt
Holt_df = test.copy()
#soothing slope = beta
fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
Holt_df['Holt_linear'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_df['Holt_linear'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\AppData\Local\Temp/ipykernel_17432/527924908.py:5: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 714.4979045355378

# %%
Holt_df['Holt_linear']
# Out:
# 2017-09-30     46874.384895
# 2017-10-31     34219.460510
# 2017-11-30     21564.536124
# 2017-12-31      8909.611739
# 2018-01-31     -3745.312647
# 2018-02-28    -16400.237032
# 2018-03-31    -29055.161418
# 2018-04-30    -41710.085803
# 2018-05-31    -54365.010188
# 2018-06-30    -67019.934574
# 2018-07-31    -79674.858959
# 2018-08-31    -92329.783345
# 2018-09-30   -104984.707730
# 2018-10-31   -117639.632116
# 2018-11-30   -130294.556501
# 2018-12-31   -142949.480887
# Freq: M, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_df['Holt_linear']))
print(rmse)
# Out:
# 190795.1159214878

# %%
#Triple ExpSmoothening
from statsmodels.tsa.api import ExponentialSmoothing
Holt_Winter_df = test.copy()
#soothing slope = beta
fit1 = ExponentialSmoothing(train,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Holt_Winter_df['Holt_Winter'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_Winter_df['Holt_Winter'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 715.1373651396473

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_Winter_df['Holt_Winter']))
print(rmse)
# Out:
# 68296.51501180546

# %%
Holt_Winter_df['Holt_Winter']
# Out:
# 2017-09-30    147545.134032
# 2017-10-31    203258.201177
# 2017-11-30    184702.192235
# 2017-12-31    148270.356608
# 2018-01-31    135149.436708
# 2018-02-28    123865.439458
# 2018-03-31    144582.719669
# 2018-04-30     77737.631977
# 2018-05-31     97050.378163
# 2018-06-30    169238.070593
# 2018-07-31    123297.057928
# 2018-08-31    147389.467978
# 2018-09-30    178901.198198
# 2018-10-31    234614.265343
# 2018-11-30    216058.256401
# 2018-12-31    179626.420774
# Freq: M, dtype: float64

# %%
from statsmodels.tsa.api import ExponentialSmoothing


fit1 = ExponentialSmoothing(y,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Y_predictions = fit1.forecast(steps=12)

y.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)

Y_predictions.plot(figsize=(10,6), title= 'Average Sales', fontsize=14) 
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Y_predictions
# Out:
# 2019-01-31    123703.125766
# 2019-02-28     93186.058287
# 2019-03-31    106269.095940
# 2019-04-30     45523.114013
# 2019-05-31     71635.077285
# 2019-06-30    144681.019853
# 2019-07-31     91536.739839
# 2019-08-31    110713.571497
# 2019-09-30    145386.089645
# 2019-10-31    178738.679824
# 2019-11-30    183423.820779
# 2019-12-31    139019.811699
# Freq: M, dtype: float64

# %%
train.plot(figsize=(20,8), title= 'Train - Average Sales ', fontsize=14,color="black",legend=True,label="Train Average Sales")
test.plot(figsize=(20,8), title='Test - Average Sales', fontsize=14,color="grey",legend=True,label="Test Average Sales")
Exp_Smooth['SES'].plot(figsize=(20,8),  fontsize=14,color="red",legend=True,label="Simple Exponential Smoothing")                                  
Holt_df['Holt_linear'].plot(figsize=(20,8),  fontsize=14,color="green",legend=True,label="Holt Linear")                                  
Holt_Winter_df['Holt_Winter'].plot(figsize=(20,8),  fontsize=14,color="blue",legend=True,label="Holt Winter") # seems Triple smooethening
Y_predictions.plot(figsize=(10,6),  fontsize=14,color="purple",legend=True,label="Predictions") 
plt.show() 
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# # ARIMA MODEL

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(y,start_p=0, max_p=3, d=None, max_d=2,start_q=0, max_q=3,  
                      start_P=0,max_P=3, D=None, max_D=2, start_Q=0, max_Q=3,
                      max_order=10, m=12, seasonal=True, information_criterion='aic',
                      test='adf',trace=True,random_state=10)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1173.555, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1175.281, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1173.687, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1171.595, Time=0.00 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=1175.551, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=1175.552, Time=0.00 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1177.445, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1173.427, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1172.260, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1172.015, Time=0.03 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.240 seconds

# %%
model
# Out:
# ARIMA(order=(0, 1, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
model.aic()
# Out:
# 1171.5953339700852

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model =SARIMAX(y, order=(0,1,1), seasonal_order=(0,0,2,12)).fit()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
Y_pred = pred.predicted_mean
Y_test = y['2018-01-01':]
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(Y_test,Y_pred))
print(rmse)
# Out:
# 694083.1150856256

# %%
#pred = model.get_prediction(start=pd.to_datetime('2017-01-31')) 
pred = model.get_forecast(steps=12)

plt.figure(figsize=(10,6))
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Validation Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
pred.predicted_mean
# Out:
# 2019-01-31    140644.685247
# 2019-02-28    103903.576818
# 2019-03-31    112332.543816
# 2019-04-30     93875.068517
# 2019-05-31    123333.915525
# 2019-06-30    150337.082609
# 2019-07-31    132009.911954
# 2019-08-31    124881.656242
# 2019-09-30    146924.904107
# 2019-10-31    121987.310268
# 2019-11-30    160399.959080
# 2019-12-31    157703.929416
# Freq: M, Name: predicted_mean, dtype: float64

# %%
#pred.predicted_mean.to_excel("Timeseriesoutput.xlsx",index=True)

# %% [markdown]
# # STATE OF UTTARKHAND

# %%
df.tail(10)
# Out:
#         FIN_YEAR MONTH        STATE            FG          DISTRICT  \
# 28630  2017-2018   Nov  Uttarakhand  Bactericides     Tehri Garhwal
# 28631  2017-2018   Oct  Uttarakhand  Bactericides       Uttar Kashi
# 28632  2017-2018   Oct  Uttarakhand  Bactericides  Udam Singh Nagar
# 28633  2017-2018   Aug  Uttarakhand  Bactericides     Tehri Garhwal
# 28634  2017-2018   Jun  Uttarakhand  Bactericides     Tehri Garhwal
# 28635  2017-2018   Sep  Uttarakhand  Bactericides     Tehri Garhwal
# 28636  2017-2018   Sep  Uttarakhand  Bactericides  Udam Singh Nagar
# 28637  2017-2018   Sep  Uttarakhand  Bactericides       Uttar Kashi
# 28638  2017-2018   Jul  Uttarakhand  Bactericides       Uttar Kashi
# 28639  2017-2018   Jul  Uttarakhand  Bactericides  Udam Singh Nagar
#
#                  COMPANY  VALUE_x     DATE_1  Rainfall in  mm     DATE_2  \
# 28630  ABC Manufacturing      0.0 2018-11-01              0.0        NaT
# 28631  ABC Manufacturing      0.0 2018-10-01              0.0        NaT
# 28632  ABC Manufacturing      0.0 2018-10-01              0.0        NaT
# 28633  ABC Manufacturing      0.0 2018-08-01              0.0 2017-08-01
# 28634  ABC Manufacturing      0.0 2018-06-01              0.0        NaT
# 28635  ABC Manufacturing      0.0 2018-09-01              0.0        NaT
# 28636  ABC Manufacturing      0.0 2018-09-01              0.0        NaT
# 28637  ABC Manufacturing      0.0 2018-09-01              0.0        NaT
# 28638  ABC Manufacturing      0.0 2018-07-01              0.0 2017-07-01
# 28639  ABC Manufacturing      0.0 2018-07-01              0.0 2017-07-01
#
#       month_full    Year As Quarter  Fiscal Year
# 28630        NaN     NaN        NaN          NaN
# 28631        NaN     NaN        NaN          NaN
# 28632        NaN     NaN        NaN          NaN
# 28633     August  2017.0     2018Q2       2018.0
# 28634        NaN     NaN        NaN          NaN
# 28635        NaN     NaN        NaN          NaN
# 28636        NaN     NaN        NaN          NaN
# 28637        NaN     NaN        NaN          NaN
# 28638       July  2017.0     2018Q2       2018.0
# 28639       July  2017.0     2018Q2       2018.0

# %%
df["STATE"].value_counts()
# Out:
# Uttar Pradesh       13024
# Haryana              6028
# Himachal Pradesh     3880
# Punjab               3668
# Uttarakhand          2040
# Name: STATE, dtype: int64

# %%
state =  df[df['STATE']=='Uttarakhand']

# %%
state.shape
# Out:
# (2040, 14)

# %%
state
# Out:
#         FIN_YEAR MONTH        STATE            FG          DISTRICT  \
# 26600  2014-2015   May  Uttarakhand  Insecticides           Chamoli
# 26601  2014-2015   May  Uttarakhand  Insecticides     Pauri Garhwal
# 26602  2014-2015   May  Uttarakhand  Insecticides       Pithoragarh
# 26603  2014-2015   May  Uttarakhand  Insecticides         Bageshwar
# 26604  2014-2015   May  Uttarakhand  Insecticides            Almora
# ...          ...   ...          ...           ...               ...
# 28635  2017-2018   Sep  Uttarakhand  Bactericides     Tehri Garhwal
# 28636  2017-2018   Sep  Uttarakhand  Bactericides  Udam Singh Nagar
# 28637  2017-2018   Sep  Uttarakhand  Bactericides       Uttar Kashi
# 28638  2017-2018   Jul  Uttarakhand  Bactericides       Uttar Kashi
# 28639  2017-2018   Jul  Uttarakhand  Bactericides  Udam Singh Nagar
#
#                  COMPANY  VALUE_x     DATE_1  Rainfall in  mm     DATE_2  \
# 26600  ABC Manufacturing    26.73 2015-05-01             48.6 2014-05-01
# 26601  ABC Manufacturing    40.50 2015-05-01             17.5 2014-05-01
# 26602  ABC Manufacturing    85.05 2015-05-01             63.8 2014-05-01
# 26603  ABC Manufacturing    75.60 2015-05-01             70.1 2014-05-01
# 26604  ABC Manufacturing   126.90 2015-05-01             42.1 2014-05-01
# ...                  ...      ...        ...              ...        ...
# 28635  ABC Manufacturing     0.00 2018-09-01              0.0        NaT
# 28636  ABC Manufacturing     0.00 2018-09-01              0.0        NaT
# 28637  ABC Manufacturing     0.00 2018-09-01              0.0        NaT
# 28638  ABC Manufacturing     0.00 2018-07-01              0.0 2017-07-01
# 28639  ABC Manufacturing     0.00 2018-07-01              0.0 2017-07-01
#
#       month_full    Year As Quarter  Fiscal Year
# 26600        May  2014.0     2015Q1       2015.0
# 26601        May  2014.0     2015Q1       2015.0
# 26602        May  2014.0     2015Q1       2015.0
# 26603        May  2014.0     2015Q1       2015.0
# 26604        May  2014.0     2015Q1       2015.0
# ...          ...     ...        ...          ...
# 28635        NaN     NaN        NaN          NaN
# 28636        NaN     NaN        NaN          NaN
# 28637        NaN     NaN        NaN          NaN
# 28638       July  2017.0     2018Q2       2018.0
# 28639       July  2017.0     2018Q2       2018.0
#
# [2040 rows x 14 columns]

# %%
df1 =state[['DATE_1','VALUE_x']]

# %%
df1= df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1
# Out:
#           DATE_1  VALUE_x
# 26884 2015-01-01   629.10
# 26902 2015-01-01    18.90
# 26903 2015-01-01    14.85
# 26904 2015-01-01    64.53
# 26905 2015-01-01     0.00
# ...          ...      ...
# 28469 2018-12-01     0.00
# 28470 2018-12-01     0.00
# 28471 2018-12-01     0.00
# 28473 2018-12-01     0.00
# 28453 2018-12-01   128.25
#
# [2040 rows x 2 columns]

# %%
df1['DATE_1'].min(), df1['DATE_1'].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2018-12-01 00:00:00'))

# %%
df1.head()
# Out:
#           DATE_1  VALUE_x
# 26884 2015-01-01   629.10
# 26902 2015-01-01    18.90
# 26903 2015-01-01    14.85
# 26904 2015-01-01    64.53
# 26905 2015-01-01     0.00

# %%
df1["DATE_1"].value_counts()
# Out:
# 2015-07-01    52
# 2015-08-01    52
# 2015-09-01    52
# 2015-10-01    52
# 2015-11-01    52
# 2016-12-01    48
# 2018-06-01    48
# 2017-03-01    48
# 2017-07-01    48
# 2015-02-01    48
# 2017-10-01    48
# 2016-10-01    48
# 2017-12-01    48
# 2018-01-01    48
# 2016-06-01    48
# 2018-09-01    48
# 2016-02-01    48
# 2016-01-01    48
# 2015-12-01    48
# 2015-06-01    48
# 2015-05-01    48
# 2018-11-01    48
# 2017-06-01    48
# 2018-05-01    44
# 2017-05-01    44
# 2017-11-01    44
# 2017-08-01    44
# 2018-10-01    44
# 2015-01-01    44
# 2018-12-01    44
# 2017-01-01    44
# 2016-11-01    44
# 2016-08-01    44
# 2016-07-01    44
# 2017-02-01    44
# 2016-05-01    44
# 2015-03-01    40
# 2018-07-01    40
# 2018-08-01    40
# 2017-09-01    36
# 2016-09-01    36
# 2016-03-01    36
# 2016-04-01    32
# 2015-04-01    32
# 2018-04-01    28
# 2017-04-01    24
# Name: DATE_1, dtype: int64

# %%
df1.dtypes
# Out:
# DATE_1     datetime64[ns]
# VALUE_x           float64
# dtype: object

# %%
df1 = df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1.head(10)
# Out:
#           DATE_1   VALUE_x
# 26884 2015-01-01   629.100
# 26900 2015-01-01   187.245
# 26913 2015-01-01     0.000
# 26898 2015-01-01     0.000
# 27159 2015-01-01     0.000
# 27158 2015-01-01     0.000
# 26888 2015-01-01    95.850
# 26889 2015-01-01    74.250
# 26890 2015-01-01  2470.365
# 26891 2015-01-01  7316.460

# %%
df1 = df1.groupby('DATE_1')["VALUE_x"].sum().reset_index()
df1.shape
# Out:
# (46, 2)

# %%
df1.head(10)
# Out:
#       DATE_1    VALUE_x
# 0 2015-01-01  34961.355
# 1 2015-02-01  47755.305
# 2 2015-03-01  45034.380
# 3 2015-04-01  33580.710
# 4 2015-05-01  34247.070
# 5 2015-06-01  57970.215
# 6 2015-07-01  65174.895
# 7 2015-08-01  35574.525
# 8 2015-09-01  40954.545
# 9 2015-10-01  40054.230

# %%
df1 = df1.set_index("DATE_1")

# %%
df1.head(10)
# Out:
#               VALUE_x
# DATE_1
# 2015-01-01  34961.355
# 2015-02-01  47755.305
# 2015-03-01  45034.380
# 2015-04-01  33580.710
# 2015-05-01  34247.070
# 2015-06-01  57970.215
# 2015-07-01  65174.895
# 2015-08-01  35574.525
# 2015-09-01  40954.545
# 2015-10-01  40054.230

# %%
df1.dtypes
# Out:
# VALUE_x    float64
# dtype: object

# %%
y = df1['VALUE_x'].resample('M').sum()

# %%
y
# Out:
# DATE_1
# 2015-01-31    34961.355
# 2015-02-28    47755.305
# 2015-03-31    45034.380
# 2015-04-30    33580.710
# 2015-05-31    34247.070
# 2015-06-30    57970.215
# 2015-07-31    65174.895
# 2015-08-31    35574.525
# 2015-09-30    40954.545
# 2015-10-31    40054.230
# 2015-11-30    63983.655
# 2015-12-31    47099.070
# 2016-01-31    53344.980
# 2016-02-29    39875.490
# 2016-03-31    40543.065
# 2016-04-30    29367.900
# 2016-05-31    59180.490
# 2016-06-30    65231.460
# 2016-07-31    62417.115
# 2016-08-31    32468.850
# 2016-09-30    32484.510
# 2016-10-31    54838.890
# 2016-11-30    55205.820
# 2016-12-31    48965.715
# 2017-01-31    29767.635
# 2017-02-28    25739.100
# 2017-03-31    42775.155
# 2017-04-30    33555.735
# 2017-05-31    65009.790
# 2017-06-30    47139.975
# 2017-07-31    55507.680
# 2017-08-31    40305.735
# 2017-09-30    31906.305
# 2017-10-31    28755.135
# 2017-11-30    68877.270
# 2017-12-31    66366.405
# 2018-01-31    51922.350
# 2018-02-28        0.000
# 2018-03-31        0.000
# 2018-04-30    22535.820
# 2018-05-31    42045.075
# 2018-06-30    67668.615
# 2018-07-31    42635.160
# 2018-08-31    34859.835
# 2018-09-30    20928.105
# 2018-10-31    40825.080
# 2018-11-30    55837.890
# 2018-12-31    62852.625
# Freq: M, Name: VALUE_x, dtype: float64

# %%
print(y.shape)
# Out:
# (48,)

# %%
y.isnull().sum()
# Out:
# 0

# %%
y.plot(figsize=(20,8))
plt.show()

# %%
train = y.loc[:'2017-08-31']
print(train.shape)
train
# Out:
# (32,)
# DATE_1
# 2015-01-31    34961.355
# 2015-02-28    47755.305
# 2015-03-31    45034.380
# 2015-04-30    33580.710
# 2015-05-31    34247.070
# 2015-06-30    57970.215
# 2015-07-31    65174.895
# 2015-08-31    35574.525
# 2015-09-30    40954.545
# 2015-10-31    40054.230
# 2015-11-30    63983.655
# 2015-12-31    47099.070
# 2016-01-31    53344.980
# 2016-02-29    39875.490
# 2016-03-31    40543.065
# 2016-04-30    29367.900
# 2016-05-31    59180.490
# 2016-06-30    65231.460
# 2016-07-31    62417.115
# 2016-08-31    32468.850
# 2016-09-30    32484.510
# 2016-10-31    54838.890
# 2016-11-30    55205.820
# 2016-12-31    48965.715
# 2017-01-31    29767.635
# 2017-02-28    25739.100
# 2017-03-31    42775.155
# 2017-04-30    33555.735
# 2017-05-31    65009.790
# 2017-06-30    47139.975
# 2017-07-31    55507.680
# 2017-08-31    40305.735
# Freq: M, Name: VALUE_x, dtype: float64

# %%
test = y.loc['2017-09-30':]
print(test.shape)
test
# Out:
# (16,)
# DATE_1
# 2017-09-30    31906.305
# 2017-10-31    28755.135
# 2017-11-30    68877.270
# 2017-12-31    66366.405
# 2018-01-31    51922.350
# 2018-02-28        0.000
# 2018-03-31        0.000
# 2018-04-30    22535.820
# 2018-05-31    42045.075
# 2018-06-30    67668.615
# 2018-07-31    42635.160
# 2018-08-31    34859.835
# 2018-09-30    20928.105
# 2018-10-31    40825.080
# 2018-11-30    55837.890
# 2018-12-31    62852.625
# Freq: M, Name: VALUE_x, dtype: float64

# %%
train.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
test.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
plt.show()

# %%
#determining rolling statistics (rolling mean at yearly level window=12)
rolmean=company1.rolling(window=12).mean()


print(rolmean)
# Out:
#                  VALUE_x
# DATE_1
# 2015-01-01           NaN
# 2015-02-01           NaN
# 2015-03-01           NaN
# 2015-04-01           NaN
# 2015-05-01           NaN
# 2015-06-01           NaN
# 2015-07-01           NaN
# 2015-08-01           NaN
# 2015-09-01           NaN
# 2015-10-01           NaN
# 2015-11-01           NaN
# 2015-12-01  153625.83750
# 2016-01-01  165642.14250
# 2016-02-01  164520.65250
# 2016-03-01  179763.58125
# 2016-04-01  188904.22875
# 2016-05-01  206816.73750
# 2016-06-01  209434.07250
# 2016-07-01  214646.37750
# 2016-08-01  217908.63000
# 2016-09-01  224382.58875
# 2016-10-01  234438.13125
# 2016-11-01  231652.90125
# 2016-12-01  230407.14375
# 2017-01-01  214415.46000
# 2017-02-01  218350.98000
# 2017-03-01  217364.73750
# 2017-04-01  196819.96500
# 2017-05-01  172493.97750
# 2017-06-01  171110.46375
# 2017-07-01  168902.07750
# 2017-08-01  175608.66375
# 2017-09-01  172625.83875
# 2017-10-01  154423.74375
# 2017-11-01  160256.76750
# 2017-12-01  161897.06250
# 2018-01-01  164557.41750
# 2018-04-01  156400.23375
# 2018-05-01  148974.63750
# 2018-06-01  158516.84250
# 2018-07-01  157798.33875
# 2018-08-01  160481.20500
# 2018-09-01  162685.23750
# 2018-10-01  160948.49625
# 2018-11-01  167333.53500
# 2018-12-01  162369.67500

# %%
rolstd=company1.rolling(window=12).std()
print(rolstd)
# Out:
#                   VALUE_x
# DATE_1
# 2015-01-01            NaN
# 2015-02-01            NaN
# 2015-03-01            NaN
# 2015-04-01            NaN
# 2015-05-01            NaN
# 2015-06-01            NaN
# 2015-07-01            NaN
# 2015-08-01            NaN
# 2015-09-01            NaN
# 2015-10-01            NaN
# 2015-11-01            NaN
# 2015-12-01   65451.112003
# 2016-01-01   69716.346159
# 2016-02-01   70649.893828
# 2016-03-01   61746.285042
# 2016-04-01   69659.937528
# 2016-05-01   92367.786672
# 2016-06-01   91093.824660
# 2016-07-01   85886.139583
# 2016-08-01   83915.516267
# 2016-09-01   78090.034331
# 2016-10-01   95380.058095
# 2016-11-01   97454.781643
# 2016-12-01   98014.881246
# 2017-01-01  108913.969231
# 2017-02-01  105389.199889
# 2017-03-01  105344.481717
# 2017-04-01  113346.493534
# 2017-05-01   95876.822828
# 2017-06-01   95832.769862
# 2017-07-01   96358.905916
# 2017-08-01  100580.841047
# 2017-09-01  100543.297030
# 2017-10-01   63280.100242
# 2017-11-01   66050.709940
# 2017-12-01   66913.092981
# 2018-01-01   63098.438529
# 2018-04-01   70731.357684
# 2018-05-01   68511.484801
# 2018-06-01   60143.820089
# 2018-07-01   60855.114915
# 2018-08-01   61963.511526
# 2018-09-01   61473.053200
# 2018-10-01   58404.391996
# 2018-11-01   62053.145647
# 2018-12-01   60873.228305

# %%
#plotting rolling statistics (Rolling Mean)
orig=plt.plot(y,color='blue',label="Original")
mean=plt.plot(rolmean,color='red',label='Rolling Mean')
#std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Rolling Mean ")
plt.show(block=True)

# %%
#plotting rolling statistics(Rolling Deviation)
orig=plt.plot(y,color='blue',label="Original")
#mean=plt.plot(rolmean,color='red',label='Rolling Mean')
std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Standard Deviation")
plt.show(block=False)

# %%
#ADFULLER test
from statsmodels.tsa.stattools import adfuller
print("ADfuller test")
dftest = adfuller(y,autolag ='AIC')
dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','number of observations used'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)'%key]= value
print(dfoutput)

# # we reject null hypothesis : It is Stationary
# Out:
# ADfuller test
# Test Statistic                 -3.539575
# p-value                         0.007027
# #lags used                      3.000000
# number of observations used    44.000000
# critical value (1%)            -3.588573
# critical value (5%)            -2.929886
# critical value (10%)           -2.603185
# dtype: float64

# %%
#Simple ExpSmoothening
from statsmodels.tsa.api import SimpleExpSmoothing
Exp_Smooth = test.copy()
fit1 = SimpleExpSmoothing(train).fit(smoothing_level=0.01)
Exp_Smooth['SES'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Exp_Smooth['SES'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Exp_Smooth.SES
# Out:
# 2017-09-30    45628.421271
# 2017-10-31    45628.421271
# 2017-11-30    45628.421271
# 2017-12-31    45628.421271
# 2018-01-31    45628.421271
# 2018-02-28    45628.421271
# 2018-03-31    45628.421271
# 2018-04-30    45628.421271
# 2018-05-31    45628.421271
# 2018-06-30    45628.421271
# 2018-07-31    45628.421271
# 2018-08-31    45628.421271
# 2018-09-30    45628.421271
# 2018-10-31    45628.421271
# 2018-11-30    45628.421271
# 2018-12-31    45628.421271
# Freq: M, dtype: float64

# %%
fit1.aic
# Out:
# 604.6311928540739

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Exp_Smooth.SES))
print(rmse)
# Out:
# 22133.093659463215

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(y)
fig = decomposition.plot()
plt.show()

# %%
# Double ExpSmoothening
from statsmodels.tsa.api import Holt
Holt_df = test.copy()
#soothing slope = beta
fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
Holt_df['Holt_linear'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_df['Holt_linear'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\AppData\Local\Temp/ipykernel_17432/527924908.py:5: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 616.5430098789362

# %%
Holt_df['Holt_linear']
# Out:
# 2017-09-30    43876.035100
# 2017-10-31    45372.662385
# 2017-11-30    46869.289670
# 2017-12-31    48365.916955
# 2018-01-31    49862.544240
# 2018-02-28    51359.171525
# 2018-03-31    52855.798810
# 2018-04-30    54352.426095
# 2018-05-31    55849.053380
# 2018-06-30    57345.680665
# 2018-07-31    58842.307950
# 2018-08-31    60338.935235
# 2018-09-30    61835.562520
# 2018-10-31    63332.189805
# 2018-11-30    64828.817090
# 2018-12-31    66325.444375
# Freq: M, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_df['Holt_linear']))
print(rmse)
# Out:
# 26407.48108573912

# %%
#Triple ExpSmoothening
from statsmodels.tsa.api import ExponentialSmoothing
Holt_Winter_df = test.copy()
#soothing slope = beta
fit1 = ExponentialSmoothing(train,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Holt_Winter_df['Holt_Winter'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_Winter_df['Holt_Winter'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 617.3970319256739

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_Winter_df['Holt_Winter']))
print(rmse)
# Out:
# 18931.704239535047

# %%
Holt_Winter_df['Holt_Winter']
# Out:
# 2017-09-30    34637.347150
# 2017-10-31    51560.807589
# 2017-11-30    57280.690985
# 2017-12-31    48729.967968
# 2018-01-31    34644.279689
# 2018-02-28    30369.903632
# 2018-03-31    43754.165586
# 2018-04-30    34053.361860
# 2018-05-31    63295.508631
# 2018-06-30    51834.477939
# 2018-07-31    58523.085364
# 2018-08-31    34381.490995
# 2018-09-30    35832.607147
# 2018-10-31    52756.067586
# 2018-11-30    58475.950982
# 2018-12-31    49925.227965
# Freq: M, dtype: float64

# %%
from statsmodels.tsa.api import ExponentialSmoothing


fit1 = ExponentialSmoothing(y,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Y_predictions = fit1.forecast(steps=12)

y.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)

Y_predictions.plot(figsize=(10,6), title= 'Average Sales', fontsize=14) 
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Y_predictions
# Out:
# 2019-01-31    37481.420246
# 2019-02-28     6870.733902
# 2019-03-31    12569.559556
# 2019-04-30    22026.688842
# 2019-05-31    44082.896625
# 2019-06-30    56393.553802
# 2019-07-31    44330.734514
# 2019-08-31    30776.090423
# 2019-09-30    21193.569933
# 2019-10-31    34084.714097
# 2019-11-30    54212.124191
# 2019-12-31    48443.512607
# Freq: M, dtype: float64

# %%
train.plot(figsize=(20,8), title= 'Train - Average Sales ', fontsize=14,color="black",legend=True,label="Train Average Sales")
test.plot(figsize=(20,8), title='Test - Average Sales', fontsize=14,color="grey",legend=True,label="Test Average Sales")
Exp_Smooth['SES'].plot(figsize=(20,8),  fontsize=14,color="red",legend=True,label="Simple Exponential Smoothing")                                  
Holt_df['Holt_linear'].plot(figsize=(20,8),  fontsize=14,color="green",legend=True,label="Holt Linear")                                  
Holt_Winter_df['Holt_Winter'].plot(figsize=(20,8),  fontsize=14,color="blue",legend=True,label="Holt Winter") # seems Triple smooethening
Y_predictions.plot(figsize=(10,6),  fontsize=14,color="purple",legend=True,label="Predictions") 
plt.show() 
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# # ARIMA MODEL

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(y,start_p=0, max_p=3, d=None, max_d=2,start_q=0, max_q=3,  
                      start_P=0,max_P=3, D=None, max_D=2, start_Q=0, max_Q=3,
                      max_order=10, m=12, seasonal=True, information_criterion='aic',
                      test='adf',trace=True,random_state=10)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1069.003, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1063.308, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1061.781, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1169.986, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=1063.497, Time=0.01 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=1063.508, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=1060.194, Time=0.08 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=1062.139, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,3)[12] intercept   : AIC=1061.984, Time=0.13 sec
#  ARIMA(0,0,1)(1,0,3)[12] intercept   : AIC=1063.942, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=1064.499, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=1062.019, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=1059.039, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=1057.164, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=1055.999, Time=0.03 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=1057.648, Time=0.08 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=1059.162, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=1059.183, Time=0.03 sec
#  ARIMA(0,0,3)(0,0,0)[12] intercept   : AIC=1053.466, Time=0.03 sec
#  ARIMA(0,0,3)(1,0,0)[12] intercept   : AIC=1055.297, Time=0.15 sec
#  ARIMA(0,0,3)(0,0,1)[12] intercept   : AIC=1053.715, Time=0.09 sec
#  ARIMA(0,0,3)(1,0,1)[12] intercept   : AIC=1055.715, Time=0.12 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=1051.446, Time=0.08 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=1051.726, Time=0.27 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=1052.220, Time=0.12 sec
#  ARIMA(1,0,3)(1,0,1)[12] intercept   : AIC=1053.722, Time=0.27 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=1047.944, Time=0.09 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=1048.695, Time=0.37 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=1048.672, Time=0.15 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=1050.537, Time=0.36 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=1053.812, Time=0.05 sec
#  ARIMA(3,0,3)(0,0,0)[12] intercept   : AIC=1048.266, Time=0.10 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=1050.469, Time=0.06 sec
#  ARIMA(2,0,3)(0,0,0)[12]             : AIC=1063.852, Time=0.12 sec
#
# Best model:  ARIMA(2,0,3)(0,0,0)[12] intercept
# Total fit time: 3.633 seconds

# %%
model
# Out:
# ARIMA(order=(2, 0, 3), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
model.aic()
# Out:
# 1047.9442747625048

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model =SARIMAX(y, order=(0,1,1), seasonal_order=(0,0,2,12)).fit()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
Y_pred = pred.predicted_mean
Y_test = y['2018-01-01':]
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(Y_test,Y_pred))
print(rmse)
# Out:
# 95000.75341418928

# %%
#pred = model.get_prediction(start=pd.to_datetime('2017-01-31')) 
pred = model.get_forecast(steps=12)

plt.figure(figsize=(10,6))
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Validation Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
pred.predicted_mean
# Out:
# 2019-01-31    39758.781809
# 2019-02-28    23029.030640
# 2019-03-31    26227.489929
# 2019-04-30    34267.055019
# 2019-05-31    42132.372030
# 2019-06-30    47037.204295
# 2019-07-31    40364.544577
# 2019-08-31    39474.002185
# 2019-09-30    32925.583784
# 2019-10-31    35410.660564
# 2019-11-30    48977.753704
# 2019-12-31    49740.072603
# Freq: M, Name: predicted_mean, dtype: float64

# %%
#pred.predicted_mean.to_excel("Timeseriesoutput.xlsx",index=True)

# %% [markdown]
# # STATE OF HIMACHAL PRADESH

# %%
df.head(10)
# Out:
#     FIN_YEAR MONTH    STATE            FG     DISTRICT            COMPANY  \
# 0  2014-2015   May  Haryana  Insecticides       Ambala  ABC Manufacturing
# 1  2014-2015   May  Haryana  Insecticides  Yamunanagar  ABC Manufacturing
# 2  2014-2015   May  Haryana  Insecticides  Kurukshetra  ABC Manufacturing
# 3  2014-2015   May  Haryana  Insecticides       Karnal  ABC Manufacturing
# 4  2014-2015   May  Haryana  Insecticides      Panipat  ABC Manufacturing
# 5  2014-2015   May  Haryana  Insecticides         Jind  ABC Manufacturing
# 6  2014-2015   May  Haryana  Insecticides    Fatehabad  ABC Manufacturing
# 7  2014-2015   May  Haryana  Insecticides        Hisar  ABC Manufacturing
# 8  2014-2015   May  Haryana  Insecticides      Bhiwani  ABC Manufacturing
# 9  2014-2015   May  Haryana  Insecticides       Rohtak  ABC Manufacturing
#
#     VALUE_x     DATE_1  Rainfall in  mm     DATE_2 month_full    Year  \
# 0   252.720 2015-05-01             20.5 2014-05-01        May  2014.0
# 1   933.255 2015-05-01             26.8 2014-05-01        May  2014.0
# 2  2675.430 2015-05-01              4.2 2014-05-01        May  2014.0
# 3  3436.830 2015-05-01             29.7 2014-05-01        May  2014.0
# 4   472.770 2015-05-01             21.5 2014-05-01        May  2014.0
# 5  8360.415 2015-05-01             48.5 2014-05-01        May  2014.0
# 6  3989.520 2015-05-01              8.6 2014-05-01        May  2014.0
# 7  3356.910 2015-05-01             25.2 2014-05-01        May  2014.0
# 8  1738.935 2015-05-01             27.2 2014-05-01        May  2014.0
# 9   315.360 2015-05-01             11.4 2014-05-01        May  2014.0
#
#   As Quarter  Fiscal Year
# 0     2015Q1       2015.0
# 1     2015Q1       2015.0
# 2     2015Q1       2015.0
# 3     2015Q1       2015.0
# 4     2015Q1       2015.0
# 5     2015Q1       2015.0
# 6     2015Q1       2015.0
# 7     2015Q1       2015.0
# 8     2015Q1       2015.0
# 9     2015Q1       2015.0

# %%
df["STATE"].value_counts()
# Out:
# Uttar Pradesh       13024
# Haryana              6028
# Himachal Pradesh     3880
# Punjab               3668
# Uttarakhand          2040
# Name: STATE, dtype: int64

# %%
state =  df[df['STATE']=='Himachal Pradesh']

# %%
state.shape
# Out:
# (3880, 14)

# %%
state
# Out:
#        FIN_YEAR MONTH             STATE            FG         DISTRICT  \
# 6028  2014-2015   May  Himachal Pradesh  Insecticides           Kangra
# 6029  2014-2015   May  Himachal Pradesh  Insecticides            Kullu
# 6030  2014-2015   May  Himachal Pradesh  Insecticides            Mandi
# 6031  2014-2015   May  Himachal Pradesh  Insecticides         Hamirpur
# 6032  2014-2015   May  Himachal Pradesh  Insecticides              Una
# ...         ...   ...               ...           ...              ...
# 9903  2017-2018   Aug  Himachal Pradesh  Bactericides           Shimla
# 9904  2017-2018   Jul  Himachal Pradesh  Bactericides  Lahul And Spiti
# 9905  2017-2018   Jul  Himachal Pradesh  Bactericides           Shimla
# 9906  2017-2018   Oct  Himachal Pradesh  Bactericides           Shimla
# 9907  2017-2018   Sep  Himachal Pradesh  Bactericides           Shimla
#
#                 COMPANY   VALUE_x     DATE_1  Rainfall in  mm     DATE_2  \
# 6028  ABC Manufacturing  2236.815 2015-05-01             45.2 2014-05-01
# 6029  ABC Manufacturing     0.000 2015-05-01            114.6 2014-05-01
# 6030  ABC Manufacturing    15.390 2015-05-01            102.9 2014-05-01
# 6031  ABC Manufacturing  2725.650 2015-05-01             55.5 2014-05-01
# 6032  ABC Manufacturing  2093.310 2015-05-01             35.0 2014-05-01
# ...                 ...       ...        ...              ...        ...
# 9903  ABC Manufacturing     0.000 2018-08-01              0.0 2017-08-01
# 9904  ABC Manufacturing     0.000 2018-07-01              0.0 2017-07-01
# 9905  ABC Manufacturing     0.000 2018-07-01              0.0 2017-07-01
# 9906  ABC Manufacturing     0.000 2018-10-01              0.0        NaT
# 9907  ABC Manufacturing     0.000 2018-09-01              0.0        NaT
#
#      month_full    Year As Quarter  Fiscal Year
# 6028        May  2014.0     2015Q1       2015.0
# 6029        May  2014.0     2015Q1       2015.0
# 6030        May  2014.0     2015Q1       2015.0
# 6031        May  2014.0     2015Q1       2015.0
# 6032        May  2014.0     2015Q1       2015.0
# ...         ...     ...        ...          ...
# 9903     August  2017.0     2018Q2       2018.0
# 9904       July  2017.0     2018Q2       2018.0
# 9905       July  2017.0     2018Q2       2018.0
# 9906        NaN     NaN        NaN          NaN
# 9907        NaN     NaN        NaN          NaN
#
# [3880 rows x 14 columns]

# %%
df1 =state[['DATE_1','VALUE_x']]

# %%
df1= df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1
# Out:
#          DATE_1  VALUE_x
# 6300 2015-01-01    33.75
# 6321 2015-01-01     0.00
# 6322 2015-01-01     0.00
# 6323 2015-01-01     0.00
# 6324 2015-01-01     0.00
# ...         ...      ...
# 9757 2018-12-01     0.00
# 9758 2018-12-01     0.00
# 9759 2018-12-01     0.00
# 9761 2018-12-01     0.00
# 9746 2018-12-01   472.50
#
# [3880 rows x 2 columns]

# %%
df1['DATE_1'].min(), df1['DATE_1'].max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2018-12-01 00:00:00'))

# %%
df1.head()
# Out:
#          DATE_1  VALUE_x
# 6300 2015-01-01    33.75
# 6321 2015-01-01     0.00
# 6322 2015-01-01     0.00
# 6323 2015-01-01     0.00
# 6324 2015-01-01     0.00

# %%
df1["DATE_1"].value_counts()
# Out:
# 2017-06-01    268
# 2017-09-01    264
# 2017-10-01    244
# 2017-05-01    240
# 2017-03-01    232
# 2017-07-01    232
# 2017-12-01    228
# 2017-02-01    224
# 2017-01-01    196
# 2017-11-01    192
# 2017-08-01    148
# 2015-10-01     48
# 2015-11-01     48
# 2015-06-01     48
# 2018-05-01     48
# 2016-06-01     48
# 2016-07-01     48
# 2016-09-01     48
# 2018-06-01     44
# 2017-04-01     44
# 2018-11-01     44
# 2015-01-01     44
# 2018-12-01     44
# 2016-11-01     44
# 2016-10-01     44
# 2016-08-01     44
# 2016-04-01     44
# 2016-03-01     44
# 2016-01-01     44
# 2015-12-01     44
# 2015-02-01     40
# 2018-07-01     40
# 2018-04-01     40
# 2018-01-01     40
# 2015-08-01     40
# 2016-02-01     40
# 2016-05-01     40
# 2016-12-01     40
# 2015-07-01     36
# 2015-05-01     36
# 2018-09-01     36
# 2015-04-01     32
# 2018-08-01     24
# 2015-03-01     24
# 2015-09-01     20
# 2018-10-01     20
# Name: DATE_1, dtype: int64

# %%
df1.dtypes
# Out:
# DATE_1     datetime64[ns]
# VALUE_x           float64
# dtype: object

# %%
df1 = df1.sort_values('DATE_1', ascending=True)
df1.isnull().sum()
# Out:
# DATE_1     0
# VALUE_x    0
# dtype: int64

# %%
df1.head(10)
# Out:
#          DATE_1   VALUE_x
# 6300 2015-01-01    33.750
# 6318 2015-01-01   121.500
# 6303 2015-01-01  1845.450
# 6304 2015-01-01  3678.750
# 6305 2015-01-01  1440.855
# 6306 2015-01-01  1864.350
# 6307 2015-01-01  1647.000
# 6302 2015-01-01    47.520
# 6468 2015-01-01     0.000
# 6474 2015-01-01     0.000

# %%
df1 = df1.groupby('DATE_1')["VALUE_x"].sum().reset_index()
df1.shape
# Out:
# (46, 2)

# %%
df1.head(10)
# Out:
#       DATE_1    VALUE_x
# 0 2015-01-01  21497.670
# 1 2015-02-01  12344.535
# 2 2015-03-01   2396.790
# 3 2015-04-01   6969.780
# 4 2015-05-01  10023.480
# 5 2015-06-01  18159.390
# 6 2015-07-01  14409.630
# 7 2015-08-01   7495.875
# 8 2015-09-01    165.375
# 9 2015-10-01  13826.835

# %%
df1 = df1.set_index("DATE_1")

# %%
df1.head(10)
# Out:
#               VALUE_x
# DATE_1
# 2015-01-01  21497.670
# 2015-02-01  12344.535
# 2015-03-01   2396.790
# 2015-04-01   6969.780
# 2015-05-01  10023.480
# 2015-06-01  18159.390
# 2015-07-01  14409.630
# 2015-08-01   7495.875
# 2015-09-01    165.375
# 2015-10-01  13826.835

# %%
df1.dtypes
# Out:
# VALUE_x    float64
# dtype: object

# %%
y = df1['VALUE_x'].resample('M').sum()

# %%
y
# Out:
# DATE_1
# 2015-01-31    21497.670
# 2015-02-28    12344.535
# 2015-03-31     2396.790
# 2015-04-30     6969.780
# 2015-05-31    10023.480
# 2015-06-30    18159.390
# 2015-07-31    14409.630
# 2015-08-31     7495.875
# 2015-09-30      165.375
# 2015-10-31    13826.835
# 2015-11-30    24801.930
# 2015-12-31    16783.740
# 2016-01-31    15356.250
# 2016-02-29     8318.295
# 2016-03-31    21547.080
# 2016-04-30    16622.820
# 2016-05-31     7457.400
# 2016-06-30    21232.530
# 2016-07-31    14526.675
# 2016-08-31    14110.470
# 2016-09-30    16156.800
# 2016-10-31    21325.950
# 2016-11-30    14076.855
# 2016-12-31    16709.220
# 2017-01-31     7311.870
# 2017-02-28    16147.485
# 2017-03-31    15161.580
# 2017-04-30     1407.780
# 2017-05-31    15280.110
# 2017-06-30    15497.595
# 2017-07-31    14288.805
# 2017-08-31     7198.335
# 2017-09-30    24069.150
# 2017-10-31    18596.250
# 2017-11-30    13007.385
# 2017-12-31    11162.610
# 2018-01-31    15490.440
# 2018-02-28        0.000
# 2018-03-31        0.000
# 2018-04-30     7897.095
# 2018-05-31    10102.455
# 2018-06-30     6543.450
# 2018-07-31    17274.870
# 2018-08-31     2613.465
# 2018-09-30    11216.475
# 2018-10-31      512.595
# 2018-11-30    26836.380
# 2018-12-31    21768.750
# Freq: M, Name: VALUE_x, dtype: float64

# %%
print(y.shape)
# Out:
# (48,)

# %%
y.isnull().sum()
# Out:
# 0

# %%
y.plot(figsize=(20,8))
plt.show()

# %%
train = y.loc[:'2017-08-31']
print(train.shape)
train
# Out:
# (32,)
# DATE_1
# 2015-01-31    21497.670
# 2015-02-28    12344.535
# 2015-03-31     2396.790
# 2015-04-30     6969.780
# 2015-05-31    10023.480
# 2015-06-30    18159.390
# 2015-07-31    14409.630
# 2015-08-31     7495.875
# 2015-09-30      165.375
# 2015-10-31    13826.835
# 2015-11-30    24801.930
# 2015-12-31    16783.740
# 2016-01-31    15356.250
# 2016-02-29     8318.295
# 2016-03-31    21547.080
# 2016-04-30    16622.820
# 2016-05-31     7457.400
# 2016-06-30    21232.530
# 2016-07-31    14526.675
# 2016-08-31    14110.470
# 2016-09-30    16156.800
# 2016-10-31    21325.950
# 2016-11-30    14076.855
# 2016-12-31    16709.220
# 2017-01-31     7311.870
# 2017-02-28    16147.485
# 2017-03-31    15161.580
# 2017-04-30     1407.780
# 2017-05-31    15280.110
# 2017-06-30    15497.595
# 2017-07-31    14288.805
# 2017-08-31     7198.335
# Freq: M, Name: VALUE_x, dtype: float64

# %%
test = y.loc['2017-09-30':]
print(test.shape)
test
# Out:
# (16,)
# DATE_1
# 2017-09-30    24069.150
# 2017-10-31    18596.250
# 2017-11-30    13007.385
# 2017-12-31    11162.610
# 2018-01-31    15490.440
# 2018-02-28        0.000
# 2018-03-31        0.000
# 2018-04-30     7897.095
# 2018-05-31    10102.455
# 2018-06-30     6543.450
# 2018-07-31    17274.870
# 2018-08-31     2613.465
# 2018-09-30    11216.475
# 2018-10-31      512.595
# 2018-11-30    26836.380
# 2018-12-31    21768.750
# Freq: M, Name: VALUE_x, dtype: float64

# %%
train.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
test.plot(figsize=(10,6), title = "Average Sales", fontsize = 14)
plt.show()

# %%
#determining rolling statistics (rolling mean at yearly level window=12)
rolmean=company1.rolling(window=12).mean()


print(rolmean)
# Out:
#                  VALUE_x
# DATE_1
# 2015-01-01           NaN
# 2015-02-01           NaN
# 2015-03-01           NaN
# 2015-04-01           NaN
# 2015-05-01           NaN
# 2015-06-01           NaN
# 2015-07-01           NaN
# 2015-08-01           NaN
# 2015-09-01           NaN
# 2015-10-01           NaN
# 2015-11-01           NaN
# 2015-12-01  153625.83750
# 2016-01-01  165642.14250
# 2016-02-01  164520.65250
# 2016-03-01  179763.58125
# 2016-04-01  188904.22875
# 2016-05-01  206816.73750
# 2016-06-01  209434.07250
# 2016-07-01  214646.37750
# 2016-08-01  217908.63000
# 2016-09-01  224382.58875
# 2016-10-01  234438.13125
# 2016-11-01  231652.90125
# 2016-12-01  230407.14375
# 2017-01-01  214415.46000
# 2017-02-01  218350.98000
# 2017-03-01  217364.73750
# 2017-04-01  196819.96500
# 2017-05-01  172493.97750
# 2017-06-01  171110.46375
# 2017-07-01  168902.07750
# 2017-08-01  175608.66375
# 2017-09-01  172625.83875
# 2017-10-01  154423.74375
# 2017-11-01  160256.76750
# 2017-12-01  161897.06250
# 2018-01-01  164557.41750
# 2018-04-01  156400.23375
# 2018-05-01  148974.63750
# 2018-06-01  158516.84250
# 2018-07-01  157798.33875
# 2018-08-01  160481.20500
# 2018-09-01  162685.23750
# 2018-10-01  160948.49625
# 2018-11-01  167333.53500
# 2018-12-01  162369.67500

# %%
rolstd=company1.rolling(window=12).std()
print(rolstd)
# Out:
#                   VALUE_x
# DATE_1
# 2015-01-01            NaN
# 2015-02-01            NaN
# 2015-03-01            NaN
# 2015-04-01            NaN
# 2015-05-01            NaN
# 2015-06-01            NaN
# 2015-07-01            NaN
# 2015-08-01            NaN
# 2015-09-01            NaN
# 2015-10-01            NaN
# 2015-11-01            NaN
# 2015-12-01   65451.112003
# 2016-01-01   69716.346159
# 2016-02-01   70649.893828
# 2016-03-01   61746.285042
# 2016-04-01   69659.937528
# 2016-05-01   92367.786672
# 2016-06-01   91093.824660
# 2016-07-01   85886.139583
# 2016-08-01   83915.516267
# 2016-09-01   78090.034331
# 2016-10-01   95380.058095
# 2016-11-01   97454.781643
# 2016-12-01   98014.881246
# 2017-01-01  108913.969231
# 2017-02-01  105389.199889
# 2017-03-01  105344.481717
# 2017-04-01  113346.493534
# 2017-05-01   95876.822828
# 2017-06-01   95832.769862
# 2017-07-01   96358.905916
# 2017-08-01  100580.841047
# 2017-09-01  100543.297030
# 2017-10-01   63280.100242
# 2017-11-01   66050.709940
# 2017-12-01   66913.092981
# 2018-01-01   63098.438529
# 2018-04-01   70731.357684
# 2018-05-01   68511.484801
# 2018-06-01   60143.820089
# 2018-07-01   60855.114915
# 2018-08-01   61963.511526
# 2018-09-01   61473.053200
# 2018-10-01   58404.391996
# 2018-11-01   62053.145647
# 2018-12-01   60873.228305

# %%
#plotting rolling statistics (Rolling Mean)
orig=plt.plot(y,color='blue',label="Original")
mean=plt.plot(rolmean,color='red',label='Rolling Mean')
#std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Rolling Mean ")
plt.show(block=True)

# %%
#plotting rolling statistics(Rolling Deviation)
orig=plt.plot(y,color='blue',label="Original")
#mean=plt.plot(rolmean,color='red',label='Rolling Mean')
std=plt.plot(rolstd,color='black',label="Rolling Std")
plt.legend(loc="best")
plt.title("Standard Deviation")
plt.show(block=False)

# %%
#ADFULLER test
from statsmodels.tsa.stattools import adfuller
print("ADfuller test")
dftest = adfuller(y,autolag ='AIC')
dfoutput=pd.Series(dftest[0:4],index=['Test Statistic','p-value','#lags used','number of observations used'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)'%key]= value
print(dfoutput)

# # we reject null hypothesis : It is Stationary
# Out:
# ADfuller test
# Test Statistic                -6.057631e+00
# p-value                        1.234214e-07
# #lags used                     0.000000e+00
# number of observations used    4.700000e+01
# critical value (1%)           -3.577848e+00
# critical value (5%)           -2.925338e+00
# critical value (10%)          -2.600774e+00
# dtype: float64

# %%
#Simple ExpSmoothening
from statsmodels.tsa.api import SimpleExpSmoothing
Exp_Smooth = test.copy()
fit1 = SimpleExpSmoothing(train).fit(smoothing_level=0.01)
Exp_Smooth['SES'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Exp_Smooth['SES'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Exp_Smooth.SES
# Out:
# 2017-09-30    13392.48163
# 2017-10-31    13392.48163
# 2017-11-30    13392.48163
# 2017-12-31    13392.48163
# 2018-01-31    13392.48163
# 2018-02-28    13392.48163
# 2018-03-31    13392.48163
# 2018-04-30    13392.48163
# 2018-05-31    13392.48163
# 2018-06-30    13392.48163
# 2018-07-31    13392.48163
# 2018-08-31    13392.48163
# 2018-09-30    13392.48163
# 2018-10-31    13392.48163
# 2018-11-30    13392.48163
# 2018-12-31    13392.48163
# Freq: M, dtype: float64

# %%
fit1.aic
# Out:
# 560.7784100519885

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Exp_Smooth.SES))
print(rmse)
# Out:
# 8478.020551947926

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(y)
fig = decomposition.plot()
plt.show()

# %%
# Double ExpSmoothening
from statsmodels.tsa.api import Holt
Holt_df = test.copy()
#soothing slope = beta
fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
Holt_df['Holt_linear'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_df['Holt_linear'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\AppData\Local\Temp/ipykernel_17432/527924908.py:5: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   fit1 = Holt(train).fit(smoothing_level=0.1, smoothing_slope = 0.8)
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 570.2361207112489

# %%
Holt_df['Holt_linear']
# Out:
# 2017-09-30    8417.010211
# 2017-10-31    7743.042890
# 2017-11-30    7069.075568
# 2017-12-31    6395.108246
# 2018-01-31    5721.140924
# 2018-02-28    5047.173602
# 2018-03-31    4373.206280
# 2018-04-30    3699.238958
# 2018-05-31    3025.271637
# 2018-06-30    2351.304315
# 2018-07-31    1677.336993
# 2018-08-31    1003.369671
# 2018-09-30     329.402349
# 2018-10-31    -344.564973
# 2018-11-30   -1018.532295
# 2018-12-31   -1692.499616
# Freq: M, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_df['Holt_linear']))
print(rmse)
# Out:
# 12087.079284461148

# %%
#Triple ExpSmoothening
from statsmodels.tsa.api import ExponentialSmoothing
Holt_Winter_df = test.copy()
#soothing slope = beta
fit1 = ExponentialSmoothing(train,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Holt_Winter_df['Holt_Winter'] = fit1.forecast(steps=len(test))

train.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
test.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
Holt_Winter_df['Holt_Winter'].plot(figsize=(10,6), title= 'Average Sales', fontsize=14)
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
fit1.aic
# Out:
# 596.7433726941458

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(test, Holt_Winter_df['Holt_Winter']))
print(rmse)
# Out:
# 9119.228023202984

# %%
Holt_Winter_df['Holt_Winter']
# Out:
# 2017-09-30     7670.206968
# 2017-10-31    17326.094419
# 2017-11-30    20597.023375
# 2017-12-31    17359.882551
# 2018-01-31    14809.371396
# 2018-02-28    14093.091995
# 2018-03-31    13365.525615
# 2018-04-30     7611.652601
# 2018-05-31    12310.875144
# 2018-06-30    18423.195541
# 2018-07-31    15107.952197
# 2018-08-31    11586.331844
# 2018-09-30     7893.497371
# 2018-10-31    17549.384822
# 2018-11-30    20820.313778
# 2018-12-31    17583.172954
# Freq: M, dtype: float64

# %%
from statsmodels.tsa.api import ExponentialSmoothing


fit1 = ExponentialSmoothing(y,seasonal_periods = 12, trend = 'add', seasonal='add').fit()
Y_predictions = fit1.forecast(steps=12)

y.plot(figsize=(10,6), title= 'Average Sales', fontsize=14)

Y_predictions.plot(figsize=(10,6), title= 'Average Sales', fontsize=14) 
plt.show()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
Y_predictions
# Out:
# 2019-01-31    13211.683259
# 2019-02-28     6459.598611
# 2019-03-31     5109.906412
# 2019-04-30     5237.427255
# 2019-05-31     8458.395498
# 2019-06-30    11991.106109
# 2019-07-31    13027.505003
# 2019-08-31     4480.334918
# 2019-09-30     8622.563072
# 2019-10-31     8817.315466
# 2019-11-30    18461.189142
# 2019-12-31    11092.867222
# Freq: M, dtype: float64

# %%
train.plot(figsize=(20,8), title= 'Train - Average Sales ', fontsize=14,color="black",legend=True,label="Train Average Sales")
test.plot(figsize=(20,8), title='Test - Average Sales', fontsize=14,color="grey",legend=True,label="Test Average Sales")
Exp_Smooth['SES'].plot(figsize=(20,8),  fontsize=14,color="red",legend=True,label="Simple Exponential Smoothing")                                  
Holt_df['Holt_linear'].plot(figsize=(20,8),  fontsize=14,color="green",legend=True,label="Holt Linear")                                  
Holt_Winter_df['Holt_Winter'].plot(figsize=(20,8),  fontsize=14,color="blue",legend=True,label="Holt Winter") # seems Triple smooethening
Y_predictions.plot(figsize=(10,6),  fontsize=14,color="purple",legend=True,label="Predictions") 
plt.show() 
plt.title
# Out:
# <function matplotlib.pyplot.title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs)>

# %% [markdown]
# # ARIMA MODEL

# %%
import pmdarima as pm

# %%
model = pm.auto_arima(y,start_p=0, max_p=3, d=None, max_d=2,start_q=0, max_q=3,  
                      start_P=0,max_P=3, D=None, max_D=2, start_Q=0, max_Q=3,
                      max_order=10, m=12, seasonal=True, information_criterion='aic',
                      test='adf',trace=True,random_state=10)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=995.007, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=988.426, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=975.344, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=993.017, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=976.386, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=996.631, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=976.641, Time=0.28 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=977.008, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=988.077, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=979.052, Time=0.37 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(0,1,1)(0,0,1)[12] intercept
# Total fit time: 2.578 seconds

# %%
model
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#       suppress_warnings=True)

# %%
model.aic()
# Out:
# 975.3436936281074

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model =SARIMAX(y, order=(0,1,1), seasonal_order=(0,0,2,12)).fit()
# Out:
# C:\Users\aalme\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
Y_pred = pred.predicted_mean
Y_test = y['2018-01-01':]
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(Y_test,Y_pred))
print(rmse)
# Out:
# 28899.00860924744

# %%
#pred = model.get_prediction(start=pd.to_datetime('2017-01-31')) 
pred = model.get_forecast(steps=12)

plt.figure(figsize=(10,6))
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Validation Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
pred.predicted_mean
# Out:
# 2019-01-31    13610.789336
# 2019-02-28    10309.541595
# 2019-03-31    11733.144098
# 2019-04-30    15503.548093
# 2019-05-31    11504.336515
# 2019-06-30    11164.851018
# 2019-07-31    12363.584096
# 2019-08-31    13411.316361
# 2019-09-30    10282.425596
# 2019-10-31    10130.412341
# 2019-11-30    12814.654096
# 2019-12-31    13341.125089
# Freq: M, Name: predicted_mean, dtype: float64

# %%
#pred.predicted_mean.to_excel("Timeseriesoutput.xlsx",index=True)
